# %%
import requests
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import time
import datetime as dt

print('Imports completed!')
# Out:
# Imports completed!

# %% [markdown]
# # TEAMS

# %%
url = "https://api-nba-v1.p.rapidapi.com/teams"
headers = {
	"x-rapidapi-key": "dda6cf782dmshebe3119a485b548p154863jsn7c9c31f1e7a7",
	"x-rapidapi-host": "api-nba-v1.p.rapidapi.com"
}

# Extract from url and header parameters
def extract_data(api_url, headers):
    response = requests.get(api_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"API request failed with status code: {response.status_code}")

# Clean the data
def transform_data(raw_data):
    # ID's to not be included
    exclude_ids = {37, 34, 39, 102, 103, 42, 35, 36, 49}

    # Gather Data for Teams
    teams = [
        {
            'team_id': row['id'],
            'team_code': row['code'],
            'team_name': row['name']
        }
        for row in raw_data['response']
        if 'leagues' in row and 'standard' in row['leagues']
        and row['leagues']['standard']['division'] is not None
        and row['id'] not in exclude_ids
    ]
    
    teams_df = pd.DataFrame(teams)
    return teams_df

# Load data into a table
def load_data(df, table_name, connection_string):
    engine = create_engine(connection_string)
    df.to_sql(table_name, engine, if_exists='replace', index=False)
    print(f'Data has been loaded and added to the {table_name} database')

# %%
# Run data pipeline
def run_pipeline():
    raw_data = extract_data(url, headers)
    clean_data = transform_data(raw_data)
    connection_string = 'sqlite:///teams_data.db'
    load_data(clean_data, 'teams', connection_string)
    
run_pipeline()
# Out:
# Data has been loaded and added to the teams database

# %% [markdown]
# # GAME SCORES

# %%
import pandas as pd
from sqlalchemy import create_engine

def read_data(connection_string):
    engine = create_engine(connection_string)
    query = "SELECT * FROM teams"
    df = pd.read_sql(query, con=engine)
    return df

# Read the data back from the database
connection_string = 'sqlite:///teams_data.db'
teams_data = read_data(connection_string)

# Display the data
teams_data
# Out:
#     team_id team_code               team_name
# 0         1       ATL           Atlanta Hawks
# 1         2       BOS          Boston Celtics
# 2         4       BKN           Brooklyn Nets
# 3         5       CHA       Charlotte Hornets
# 4         6       CHI           Chicago Bulls
# 5         7       CLE     Cleveland Cavaliers
# 6         8       DAL        Dallas Mavericks
# 7         9       DEN          Denver Nuggets
# 8        10       DET         Detroit Pistons
# 9        11       GSW   Golden State Warriors
# 10       14       HOU         Houston Rockets
# 11       15       IND          Indiana Pacers
# 12       16       LAC             LA Clippers
# 13       17       LAL      Los Angeles Lakers
# 14       19       MEM       Memphis Grizzlies
# 15       20       MIA              Miami Heat
# 16       21       MIL         Milwaukee Bucks
# 17       22       MIN  Minnesota Timberwolves
# 18       23       NOP    New Orleans Pelicans
# 19       24       NYK         New York Knicks
# 20       25       OKC   Oklahoma City Thunder
# 21       26       ORL           Orlando Magic
# 22       27       PHI      Philadelphia 76ers
# 23       28       PHX            Phoenix Suns
# 24       29       POR  Portland Trail Blazers
# 25       30       SAC        Sacramento Kings
# 26       31       SAS       San Antonio Spurs
# 27       38       TOR         Toronto Raptors
# 28       40       UTA               Utah Jazz
# 29       41       WAS      Washington Wizards

# %%
from itertools import permutations 
import time

url = "https://api-nba-v1.p.rapidapi.com/games"
headers = {
	"x-rapidapi-key": "dda6cf782dmshebe3119a485b548p154863jsn7c9c31f1e7a7",
	"x-rapidapi-host": "api-nba-v1.p.rapidapi.com"
}

# Get a list of all team ids (only take for 2 for example)
team_ids = teams_data['team_id'].values

def game_matches(team_ids, url, headers):
    # Use team ids to make game matches
    matchups = list(permutations(team_ids, 2))
    
    # Filter games where (id1, id2) != (id2, id1)
    unique_matchups = []
    for game in matchups:
        if game[1] > game[0]:
            unique_matchups.append((game[0], game[1]))
        else:
            continue
    
    # Create an array to store the information
    response_arr = []
    for game in unique_matchups:
        querystring = {"h2h":f"{game[0]}-{game[1]}"}
        print(f"Gathering data for matchup {game[0]}-{game[1]}")
        
        # Make the API request
        response = requests.get(url, headers=headers, params=querystring)
        
        # Check if the response is successful:
        if response.status_code == 200:
            game_data = response.json()
            response_arr.append(game_data)
        else:
            print(f"Failed to gather data for {game[0]}-{game[1]}. Status code: {response.status_code}")
        
        # Avoid hitting rate limits
        time.sleep(1)

    # Display gathered data
    return response_arr

results = game_matches(team_ids=team_ids, url=url, headers=headers)
# Out:
# Gathering data for matchup 1-2
# Gathering data for matchup 1-4
# Gathering data for matchup 1-5
# Gathering data for matchup 1-6
# Gathering data for matchup 1-7
# Gathering data for matchup 1-8
# Gathering data for matchup 1-9
# Gathering data for matchup 1-10
# Gathering data for matchup 1-11
# Gathering data for matchup 1-14
# Failed to gather data for 1-14. Status code: 429
# Gathering data for matchup 1-15
# Failed to gather data for 1-15. Status code: 429
# Gathering data for matchup 1-16
# Failed to gather data for 1-16. Status code: 429
# Gathering data for matchup 1-17
# Failed to gather data for 1-17. Status code: 429
# Gathering data for matchup 1-19
# Failed to gather data for 1-19. Status code: 429
# Gathering data for matchup 1-20
# Failed to gather data for 1-20. Status code: 429
# Gathering data for matchup 1-21
# Failed to gather data for 1-21. Status code: 429
# Gathering data for matchup 1-22
# Failed to gather data for 1-22. Status code: 429
# Gathering data for matchup 1-23
# Failed to gather data for 1-23. Status code: 429
# Gathering data for matchup 1-24
# Failed to gather data for 1-24. Status code: 429
# Gathering data for matchup 1-25
# Failed to gather data for 1-25. Status code: 429
# Gathering data for matchup 1-26
# Failed to gather data for 1-26. Status code: 429
# Gathering data for matchup 1-27
# Gathering data for matchup 1-28
# Failed to gather data for 1-28. Status code: 429
# Gathering data for matchup 1-29
# Failed to gather data for 1-29. Status code: 429
# Gathering data for matchup 1-30
# Failed to gather data for 1-30. Status code: 429
# Gathering data for matchup 1-31
# Gathering data for matchup 1-38
# Failed to gather data for 1-38. Status code: 429
# Gathering data for matchup 1-40
# Failed to gather data for 1-40. Status code: 429
# Gathering data for matchup 1-41
# Failed to gather data for 1-41. Status code: 429
# Gathering data for matchup 2-4
# Failed to gather data for 2-4. Status code: 429
# Gathering data for matchup 2-5
# Gathering data for matchup 2-6
# Failed to gather data for 2-6. Status code: 429
# Gathering data for matchup 2-7
# Failed to gather data for 2-7. Status code: 429
# Gathering data for matchup 2-8
# Failed to gather data for 2-8. Status code: 429
# Gathering data for matchup 2-9
# Gathering data for matchup 2-10
# Failed to gather data for 2-10. Status code: 429
# Failed to gather data for 5-7. Status code: 429
# Gathering data for matchup 5-8
# Failed to gather data for 5-8. Status code: 429
# Gathering data for matchup 5-9
# Failed to gather data for 5-9. Status code: 429
# Gathering data for matchup 5-10
# Gathering data for matchup 5-11
# Failed to gather data for 5-11. Status code: 429
# Gathering data for matchup 5-14
# Failed to gather data for 5-14. Status code: 429
# Gathering data for matchup 5-15
# Failed to gather data for 5-15. Status code: 429
# Gathering data for matchup 5-16
# Failed to gather data for 5-16. Status code: 429
# Gathering data for matchup 5-17
# Gathering data for matchup 5-19
# Failed to gather data for 5-19. Status code: 429
# Gathering data for matchup 5-20
# Failed to gather data for 5-20. Status code: 429
# Gathering data for matchup 5-21
# Failed to gather data for 5-21. Status code: 429
# Gathering data for matchup 5-22
# Gathering data for matchup 5-23
# Failed to gather data for 5-23. Status code: 429
# Gathering data for matchup 5-24
# Failed to gather data for 5-24. Status code: 429
# Gathering data for matchup 5-25
# Failed to gather data for 5-25. Status code: 429
# Gathering data for matchup 5-26
# Failed to gather data for 5-26. Status code: 429
# Gathering data for matchup 5-27
# Gathering data for matchup 5-28
# Failed to gather data for 5-28. Status code: 429
# Gathering data for matchup 5-29
# Failed to gather data for 5-29. Status code: 429
# Gathering data for matchup 5-30
# Failed to gather data for 5-30. Status code: 429
# Gathering data for matchup 5-31
# Failed to gather data for 5-31. Status code: 429
# Gathering data for matchup 5-38
# Gathering data for matchup 5-40
# Failed to gather data for 5-40. Status code: 429
# Gathering data for matchup 5-41
# Failed to gather data for 5-41. Status code: 429
# Gathering data for matchup 6-7
# Failed to gather data for 6-7. Status code: 429
# Gathering data for matchup 6-8
# Gathering data for matchup 6-9
# Failed to gather data for 6-9. Status code: 429
# Gathering data for matchup 6-10
# Failed to gather data for 6-10. Status code: 429
# Gathering data for matchup 6-11
# Failed to gather data for 6-11. Status code: 429
# Gathering data for matchup 6-14
# Failed to gather data for 6-14. Status code: 429
# Gathering data for matchup 6-15
# Gathering data for matchup 6-16
# Failed to gather data for 6-16. Status code: 429
# Gathering data for matchup 6-17
# Failed to gather data for 6-17. Status code: 429
# Gathering data for matchup 6-19
# Failed to gather data for 6-19. Status code: 429
# Gathering data for matchup 6-20
# Gathering data for matchup 6-21
# Failed to gather data for 6-21. Status code: 429
# Gathering data for matchup 6-22
# Failed to gather data for 6-22. Status code: 429
# Gathering data for matchup 6-23
# Failed to gather data for 6-23. Status code: 429
# Gathering data for matchup 6-24
# Failed to gather data for 6-24. Status code: 429
# Gathering data for matchup 6-25
# Gathering data for matchup 6-26
# Failed to gather data for 6-26. Status code: 429
# Gathering data for matchup 6-27
# Failed to gather data for 6-27. Status code: 429
# Gathering data for matchup 6-28
# Failed to gather data for 6-28. Status code: 429
# Gathering data for matchup 6-29
# Gathering data for matchup 6-30
# Failed to gather data for 6-30. Status code: 429
# Gathering data for matchup 6-31
# Failed to gather data for 6-31. Status code: 429
# Gathering data for matchup 6-38
# Failed to gather data for 6-38. Status code: 429
# Gathering data for matchup 6-40
# Failed to gather data for 6-40. Status code: 429
# Gathering data for matchup 6-41
# Gathering data for matchup 7-8
# Failed to gather data for 7-8. Status code: 429
# Gathering data for matchup 7-9
# Failed to gather data for 7-9. Status code: 429
# Gathering data for matchup 7-10
# Failed to gather data for 7-10. Status code: 429
# Gathering data for matchup 7-11
# Failed to gather data for 7-11. Status code: 429
# Gathering data for matchup 7-14
# Gathering data for matchup 7-15
# Failed to gather data for 7-15. Status code: 429
# Gathering data for matchup 7-16
# Failed to gather data for 7-16. Status code: 429
# Gathering data for matchup 7-17
# Failed to gather data for 7-17. Status code: 429
# Gathering data for matchup 7-19
# Gathering data for matchup 7-20
# Failed to gather data for 7-20. Status code: 429
# Gathering data for matchup 7-21
# Failed to gather data for 7-21. Status code: 429
# Gathering data for matchup 7-22
# Failed to gather data for 7-22. Status code: 429
# Gathering data for matchup 7-23
# Gathering data for matchup 7-24
# Failed to gather data for 7-24. Status code: 429
# Gathering data for matchup 7-25
# Failed to gather data for 7-25. Status code: 429
# Gathering data for matchup 7-26
# Failed to gather data for 7-26. Status code: 429
# Gathering data for matchup 7-27
# Failed to gather data for 7-27. Status code: 429
# Gathering data for matchup 7-28
# Gathering data for matchup 7-29
# Failed to gather data for 7-29. Status code: 429
# Gathering data for matchup 7-30
# Failed to gather data for 7-30. Status code: 429
# Gathering data for matchup 7-31
# Failed to gather data for 7-31. Status code: 429
# Gathering data for matchup 7-38
# Gathering data for matchup 7-40
# Failed to gather data for 7-40. Status code: 429
# Gathering data for matchup 7-41
# Failed to gather data for 7-41. Status code: 429
# Gathering data for matchup 8-9
# Failed to gather data for 8-9. Status code: 429
# Gathering data for matchup 8-10
# Failed to gather data for 8-10. Status code: 429
# Gathering data for matchup 8-11
# Gathering data for matchup 8-14
# Failed to gather data for 8-14. Status code: 429
# Gathering data for matchup 8-15
# Failed to gather data for 8-15. Status code: 429
# Gathering data for matchup 8-16
# Failed to gather data for 8-16. Status code: 429
# Gathering data for matchup 8-17
# Gathering data for matchup 8-19
# Failed to gather data for 8-19. Status code: 429
# Gathering data for matchup 8-20
# Failed to gather data for 8-20. Status code: 429
# Gathering data for matchup 8-21
# Failed to gather data for 8-21. Status code: 429
# Gathering data for matchup 8-22
# Failed to gather data for 8-22. Status code: 429
# Gathering data for matchup 8-23
# Gathering data for matchup 8-24
# Failed to gather data for 8-24. Status code: 429
# Gathering data for matchup 8-25
# Failed to gather data for 8-25. Status code: 429
# Gathering data for matchup 8-26
# Failed to gather data for 8-26. Status code: 429
# Gathering data for matchup 8-27
# Gathering data for matchup 8-28
# Failed to gather data for 8-28. Status code: 429
# Gathering data for matchup 8-29
# Failed to gather data for 8-29. Status code: 429
# Gathering data for matchup 8-30
# Gathering data for matchup 8-31
# Failed to gather data for 8-31. Status code: 429
# Gathering data for matchup 8-38
# Failed to gather data for 8-38. Status code: 429
# Gathering data for matchup 8-40
# Failed to gather data for 8-40. Status code: 429
# Gathering data for matchup 8-41
# Gathering data for matchup 9-10
# Failed to gather data for 9-10. Status code: 429
# Gathering data for matchup 9-11
# Failed to gather data for 9-11. Status code: 429
# Gathering data for matchup 9-14
# Failed to gather data for 9-14. Status code: 429
# Gathering data for matchup 40-41
# Failed to gather data for 40-41. Status code: 429

# %%
game_scores = []

for info in results:
    for game in info['response']:
        # Extract date of the game
        date = game.get('date', {}).get('start','N/A')
        
        # Extract teams info
        visitor = game.get('teams', {}).get('visitors', {}).get('name', 'Unknown')
        home = game.get('teams', {}).get('home', {}).get('name', 'Unknown')
     
        visitor_code = game.get('teams', {}).get('visitors', {}).get('code', 'N/A')
        home_code = game.get('teams', {}).get('home', {}).get('code', 'N/A') 
        
        # Initialize lists to store total scores
        visitor_total_scores = []
        home_total_scores = []
        
        # Extract scores by quarter
        visitor_scores = game.get('scores', {}).get('visitors', {}).get('linescore', [])
        home_scores = game.get('scores', {}).get('home', {}).get('linescore', [])
        
        visitor_points = game.get('scores', {}).get('visitors', {}).get('points', '0')
        home_points = game.get('scores', {}).get('home', {}).get('points', '0')
        
        if visitor_scores and home_scores and visitor_points is not None and home_points is not None:
            visitor_total_scores.append(visitor_points)
            home_total_scores.append(home_points)
        
        # Display data if scores and points exist
        if visitor_scores and home_scores and visitor_total_scores and home_total_scores:
            print(f"Date: {date}")
            print(f"Visitor Team: {visitor} ({visitor_code}) - Scores: {visitor_scores} - Total Points: {visitor_total_scores[0]}")
            print(f"Home Team: {home} ({home_code}) - Scores: {home_scores} - Total Points: {home_total_scores[0]}")
            print('-------------------------------------------')
            
        game_scores.append({
            'date': date,
            'visitor': visitor,
            'home': home,
            'visitor_points': visitor_points,
            'home_points': home_points
        })
        
    game_score_df = pd.DataFrame(game_scores)
game_score_df
# Out:
# Date: 2015-11-25T01:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '20', '25', '24'] - Total Points: 97
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '24', '24', '40'] - Total Points: 121
# -------------------------------------------
# Date: 2016-04-09T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['32', '39', '20', '16'] - Total Points: 107
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '33', '26', '25'] - Total Points: 118
# -------------------------------------------
# Date: 2016-04-16T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['19', '15', '31', '36'] - Total Points: 101
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '21', '21', '30'] - Total Points: 102
# -------------------------------------------
# Date: 2016-04-19T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['7', '21', '18', '26'] - Total Points: 72
# Home Team: Atlanta Hawks (ATL) - Scores: ['24', '19', '18', '28'] - Total Points: 89
# -------------------------------------------
# Date: 2016-04-27T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['20', '19', '23', '21'] - Total Points: 83
# Home Team: Atlanta Hawks (ATL) - Scores: ['15', '32', '42', '21'] - Total Points: 110
# -------------------------------------------
# Date: 2017-01-14T01:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '20', '30', '25'] - Total Points: 103
# Home Team: Atlanta Hawks (ATL) - Scores: ['18', '26', '21', '36'] - Total Points: 101
# -------------------------------------------
# Date: 2017-04-07T00:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['24', '31', '34', '27'] - Total Points: 116
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '39', '28', '24'] - Total Points: 123
# -------------------------------------------
# Date: 2017-11-07T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['26', '28', '28', '28'] - Total Points: 110
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '29', '21', '32'] - Total Points: 107
# -------------------------------------------
# Date: 2017-11-19T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['20', '24', '36', '30'] - Total Points: 110
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '15', '27', '22'] - Total Points: 99
# -------------------------------------------
# Date: 2018-11-24T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['45', '16', '21', '32'] - Total Points: 114
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '22', '19', '32'] - Total Points: 96
# -------------------------------------------
# Date: 2019-01-20T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '32', '23', '30'] - Total Points: 113
# Home Team: Atlanta Hawks (ATL) - Scores: ['36', '31', '22', '16'] - Total Points: 105
# -------------------------------------------
# Date: 2020-02-04T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '32', '35', '28'] - Total Points: 123
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '28', '22', '31'] - Total Points: 115
# -------------------------------------------
# Date: 2021-02-25T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['27', '22', '29', '34'] - Total Points: 112
# Home Team: Atlanta Hawks (ATL) - Scores: ['40', '32', '27', '28'] - Total Points: 127
# -------------------------------------------
# Date: 2021-11-18T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['29', '20', '28', '22'] - Total Points: 99
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '28', '33', '19'] - Total Points: 110
# -------------------------------------------
# Date: 2022-01-29T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['20', '27', '30', '15'] - Total Points: 92
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '30', '18', '28'] - Total Points: 108
# -------------------------------------------
# Date: 2022-11-17T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['30', '32', '35', '29'] - Total Points: 126
# Home Team: Atlanta Hawks (ATL) - Scores: ['18', '35', '25', '23'] - Total Points: 101
# -------------------------------------------
# Date: 2023-04-21T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['37', '30', '26', '29'] - Total Points: 122
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '41', '26', '30'] - Total Points: 130
# -------------------------------------------
# Date: 2023-04-23T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '30', '27', '37'] - Total Points: 129
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '28', '34', '34'] - Total Points: 121
# -------------------------------------------
# Date: 2023-04-28T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '33', '30', '30'] - Total Points: 128
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '33', '33', '20'] - Total Points: 120
# -------------------------------------------
# Date: 2024-03-25T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['44', '30', '22', '22'] - Total Points: 118
# Home Team: Atlanta Hawks (ATL) - Scores: ['22', '34', '34', '30'] - Total Points: 120
# -------------------------------------------
# Date: 2024-03-28T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['29', '34', '27', '22', '10'] - Total Points: 122
# Home Team: Atlanta Hawks (ATL) - Scores: ['28', '31', '30', '23', '11'] - Total Points: 123
# -------------------------------------------
# Date: 2023-03-12T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['37', '34', '30', '33'] - Total Points: 134
# Home Team: Atlanta Hawks (ATL) - Scores: ['38', '23', '28', '36'] - Total Points: 125
# -------------------------------------------
# Date: 2015-11-14T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '19', '24', '24'] - Total Points: 93
# Home Team: Boston Celtics (BOS) - Scores: ['23', '22', '35', '26'] - Total Points: 106
# -------------------------------------------
# Date: 2015-12-19T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '23', '29', '38'] - Total Points: 109
# Home Team: Boston Celtics (BOS) - Scores: ['25', '18', '30', '28'] - Total Points: 101
# -------------------------------------------
# Date: 2016-04-23T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '25', '33', '25'] - Total Points: 103
# Home Team: Boston Celtics (BOS) - Scores: ['37', '20', '22', '32'] - Total Points: 111
# -------------------------------------------
# Date: 2016-04-24T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['21', '27', '25', '19', '3'] - Total Points: 95
# Home Team: Boston Celtics (BOS) - Scores: ['24', '22', '24', '22', '12'] - Total Points: 104
# -------------------------------------------
# Date: 2016-04-29T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '21', '39', '24'] - Total Points: 104
# Home Team: Boston Celtics (BOS) - Scores: ['17', '16', '26', '33'] - Total Points: 92
# -------------------------------------------
# Date: 2017-02-28T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '27', '33', '30'] - Total Points: 114
# Home Team: Boston Celtics (BOS) - Scores: ['24', '23', '24', '27'] - Total Points: 98
# -------------------------------------------
# Date: 2018-02-03T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['32', '23', '20', '35'] - Total Points: 110
# Home Team: Boston Celtics (BOS) - Scores: ['26', '27', '41', '25'] - Total Points: 119
# -------------------------------------------
# Date: 2018-04-08T17:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '25', '27', '36'] - Total Points: 112
# Home Team: Boston Celtics (BOS) - Scores: ['31', '27', '24', '24'] - Total Points: 106
# -------------------------------------------
# Date: 2018-12-15T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '37', '26', '26'] - Total Points: 108
# Home Team: Boston Celtics (BOS) - Scores: ['42', '25', '41', '21'] - Total Points: 129
# -------------------------------------------
# Date: 2019-03-16T16:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['36', '26', '30', '28'] - Total Points: 120
# Home Team: Boston Celtics (BOS) - Scores: ['43', '31', '31', '24'] - Total Points: 129
# -------------------------------------------
# Date: 2020-01-04T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['32', '23', '25', '26'] - Total Points: 106
# Home Team: Boston Celtics (BOS) - Scores: ['19', '34', '29', '27'] - Total Points: 109
# -------------------------------------------
# Date: 2020-02-08T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '29', '18', '34'] - Total Points: 107
# Home Team: Boston Celtics (BOS) - Scores: ['28', '26', '33', '25'] - Total Points: 112
# -------------------------------------------
# Date: 2021-02-20T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['22', '19', '32', '36'] - Total Points: 109
# Home Team: Boston Celtics (BOS) - Scores: ['33', '33', '32', '23'] - Total Points: 121
# -------------------------------------------
# Date: 2021-02-18T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '29', '28', '32'] - Total Points: 122
# Home Team: Boston Celtics (BOS) - Scores: ['35', '21', '25', '33'] - Total Points: 114
# -------------------------------------------
# Date: 2022-02-13T19:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '27', '23', '17'] - Total Points: 95
# Home Team: Boston Celtics (BOS) - Scores: ['17', '28', '42', '18'] - Total Points: 105
# -------------------------------------------
# Date: 2022-03-02T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '37', '13', '20'] - Total Points: 98
# Home Team: Boston Celtics (BOS) - Scores: ['19', '32', '31', '25'] - Total Points: 107
# -------------------------------------------
# Date: 2023-04-09T17:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['31', '33', '26', '24'] - Total Points: 114
# Home Team: Boston Celtics (BOS) - Scores: ['29', '32', '39', '20'] - Total Points: 120
# -------------------------------------------
# Date: 2023-04-15T19:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '25', '31', '24'] - Total Points: 99
# Home Team: Boston Celtics (BOS) - Scores: ['29', '45', '20', '18'] - Total Points: 112
# -------------------------------------------
# Date: 2023-04-18T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '24', '32', '25'] - Total Points: 106
# Home Team: Boston Celtics (BOS) - Scores: ['28', '33', '29', '29'] - Total Points: 119
# -------------------------------------------
# Date: 2023-04-25T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['30', '28', '24', '37'] - Total Points: 119
# Home Team: Boston Celtics (BOS) - Scores: ['27', '39', '26', '25'] - Total Points: 117
# -------------------------------------------
# Date: 2023-11-26T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '27', '29', '21'] - Total Points: 103
# Home Team: Boston Celtics (BOS) - Scores: ['33', '36', '21', '23'] - Total Points: 113
# -------------------------------------------
# Date: 2024-02-08T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['37', '30', '23', '27'] - Total Points: 117
# Home Team: Boston Celtics (BOS) - Scores: ['35', '36', '24', '30'] - Total Points: 125
# -------------------------------------------
# Date: 2015-11-05T01:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['17', '26', '27', '17'] - Total Points: 87
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '18', '31', '29'] - Total Points: 101
# -------------------------------------------
# Date: 2016-01-17T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['23', '25', '20', '18'] - Total Points: 86
# Home Team: Atlanta Hawks (ATL) - Scores: ['27', '28', '29', '30'] - Total Points: 114
# -------------------------------------------
# Date: 2017-03-09T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['27', '23', '30', '25'] - Total Points: 105
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '23', '35', '29'] - Total Points: 110
# -------------------------------------------
# Date: 2017-03-26T17:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['32', '23', '23', '29'] - Total Points: 107
# Home Team: Atlanta Hawks (ATL) - Scores: ['20', '28', '20', '24'] - Total Points: 92
# -------------------------------------------
# Date: 2017-12-05T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '20', '31', '26'] - Total Points: 110
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '22', '15', '21'] - Total Points: 90
# -------------------------------------------
# Date: 2018-01-13T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['25', '28', '21', '36'] - Total Points: 110
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '25', '24', '31'] - Total Points: 105
# -------------------------------------------
# Date: 2017-07-08T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['23', '19', '22', '11'] - Total Points: 75
# Home Team: Atlanta Hawks (ATL) - Scores: ['21', '10', '17', '24'] - Total Points: 72
# -------------------------------------------
# Date: 2019-03-10T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '30', '27', '31'] - Total Points: 114
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '24', '30', '35'] - Total Points: 112
# -------------------------------------------
# Date: 2019-12-05T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['22', '34', '35', '39'] - Total Points: 130
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '21', '35', '36'] - Total Points: 118
# -------------------------------------------
# Date: 2020-02-29T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['36', '26', '36', '20'] - Total Points: 118
# Home Team: Atlanta Hawks (ATL) - Scores: ['29', '39', '40', '33'] - Total Points: 141
# -------------------------------------------
# Date: 2021-01-28T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '29', '28', '33', '16'] - Total Points: 132
# Home Team: Atlanta Hawks (ATL) - Scores: ['27', '28', '32', '29', '12'] - Total Points: 128
# -------------------------------------------
# Date: 2021-12-11T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '26', '37', '24'] - Total Points: 113
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '29', '36', '14'] - Total Points: 105
# -------------------------------------------
# Date: 2022-04-02T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['30', '20', '37', '28'] - Total Points: 115
# Home Team: Atlanta Hawks (ATL) - Scores: ['28', '37', '29', '28'] - Total Points: 122
# -------------------------------------------
# Date: 2022-12-29T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['31', '25', '27', '25'] - Total Points: 108
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '33', '17', '27'] - Total Points: 107
# -------------------------------------------
# Date: 2023-02-26T20:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['29', '28', '37', '33'] - Total Points: 127
# Home Team: Atlanta Hawks (ATL) - Scores: ['37', '27', '33', '32'] - Total Points: 129
# -------------------------------------------
# Date: 2023-11-23T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '34', '28', '36', '14'] - Total Points: 145
# Home Team: Atlanta Hawks (ATL) - Scores: ['45', '32', '23', '31', '16'] - Total Points: 147
# -------------------------------------------
# Date: 2023-12-07T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['31', '22', '28', '33'] - Total Points: 114
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '23', '26', '31'] - Total Points: 113
# -------------------------------------------
# Date: 2015-11-18T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '27', '22', '20'] - Total Points: 88
# Home Team: Brooklyn Nets (BKN) - Scores: ['17', '28', '27', '18'] - Total Points: 90
# -------------------------------------------
# Date: 2017-01-11T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['35', '26', '25', '31'] - Total Points: 117
# Home Team: Brooklyn Nets (BKN) - Scores: ['29', '14', '27', '27'] - Total Points: 97
# -------------------------------------------
# Date: 2017-04-02T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '19', '18', '21'] - Total Points: 82
# Home Team: Brooklyn Nets (BKN) - Scores: ['29', '17', '24', '21'] - Total Points: 91
# -------------------------------------------
# Date: 2017-10-22T19:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '28', '24', '27'] - Total Points: 104
# Home Team: Brooklyn Nets (BKN) - Scores: ['19', '37', '35', '25'] - Total Points: 116
# -------------------------------------------
# Date: 2017-12-02T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '29', '27', '33'] - Total Points: 114
# Home Team: Brooklyn Nets (BKN) - Scores: ['22', '23', '30', '27'] - Total Points: 102
# -------------------------------------------
# Date: 2018-12-16T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['23', '43', '30', '31'] - Total Points: 127
# Home Team: Brooklyn Nets (BKN) - Scores: ['42', '30', '39', '33'] - Total Points: 144
# -------------------------------------------
# Date: 2019-01-10T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['38', '19', '23', '20'] - Total Points: 100
# Home Team: Brooklyn Nets (BKN) - Scores: ['23', '28', '35', '30'] - Total Points: 116
# -------------------------------------------
# Date: 2019-12-21T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['34', '39', '25', '14'] - Total Points: 112
# Home Team: Brooklyn Nets (BKN) - Scores: ['34', '26', '25', '37'] - Total Points: 122
# -------------------------------------------
# Date: 2020-01-12T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['16', '30', '20', '20'] - Total Points: 86
# Home Team: Brooklyn Nets (BKN) - Scores: ['37', '33', '22', '16'] - Total Points: 108
# -------------------------------------------
# Date: 2020-12-31T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['41', '27', '36', '37'] - Total Points: 141
# Home Team: Brooklyn Nets (BKN) - Scores: ['38', '29', '35', '43'] - Total Points: 145
# -------------------------------------------
# Date: 2021-01-02T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['29', '32', '28', '25'] - Total Points: 114
# Home Team: Brooklyn Nets (BKN) - Scores: ['23', '29', '21', '23'] - Total Points: 96
# -------------------------------------------
# Date: 2021-11-03T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '31', '20', '29'] - Total Points: 108
# Home Team: Brooklyn Nets (BKN) - Scores: ['35', '26', '34', '22'] - Total Points: 117
# -------------------------------------------
# Date: 2022-12-10T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['30', '34', '26', '26'] - Total Points: 116
# Home Team: Brooklyn Nets (BKN) - Scores: ['36', '32', '28', '24'] - Total Points: 120
# -------------------------------------------
# Date: 2023-03-31T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '22', '24', '28'] - Total Points: 107
# Home Team: Brooklyn Nets (BKN) - Scores: ['25', '34', '42', '23'] - Total Points: 124
# -------------------------------------------
# Date: 2024-03-01T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['16', '34', '25', '22'] - Total Points: 97
# Home Team: Brooklyn Nets (BKN) - Scores: ['34', '22', '38', '30'] - Total Points: 124
# -------------------------------------------
# Date: 2024-03-02T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '34', '18', '22'] - Total Points: 102
# Home Team: Brooklyn Nets (BKN) - Scores: ['21', '39', '30', '24'] - Total Points: 114
# -------------------------------------------
# Date: 2015-10-31T00:00:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['22', '30', '17', '25'] - Total Points: 94
# Home Team: Atlanta Hawks (ATL) - Scores: ['29', '24', '23', '21'] - Total Points: 97
# -------------------------------------------
# Date: 2016-02-28T20:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['9', '23', '25', '19'] - Total Points: 76
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '21', '22', '19'] - Total Points: 87
# -------------------------------------------
# Date: 2016-12-18T00:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['22', '31', '27', '27'] - Total Points: 107
# Home Team: Atlanta Hawks (ATL) - Scores: ['22', '20', '32', '25'] - Total Points: 99
# -------------------------------------------
# Date: 2017-04-11T23:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['26', '18', '17', '15'] - Total Points: 76
# Home Team: Atlanta Hawks (ATL) - Scores: ['38', '25', '21', '19'] - Total Points: 103
# -------------------------------------------
# Date: 2018-02-01T00:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['35', '29', '33', '26'] - Total Points: 123
# Home Team: Atlanta Hawks (ATL) - Scores: ['28', '24', '32', '26'] - Total Points: 110
# -------------------------------------------
# Date: 2018-03-15T23:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['33', '30', '34', '32'] - Total Points: 129
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '32', '24', '38'] - Total Points: 117
# -------------------------------------------
# Date: 2018-11-25T23:00:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['43', '23', '31', '26'] - Total Points: 123
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '33', '35', '24'] - Total Points: 124
# -------------------------------------------
# Date: 2019-02-10T00:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['46', '27', '33', '23'] - Total Points: 129
# Home Team: Atlanta Hawks (ATL) - Scores: ['31', '37', '18', '34'] - Total Points: 120
# -------------------------------------------
# Date: 2020-03-09T23:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['32', '31', '31', '28', '9', '7'] - Total Points: 138
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '34', '32', '24', '9', '12'] - Total Points: 143
# -------------------------------------------
# Date: 2021-01-07T00:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['27', '32', '22', '21'] - Total Points: 102
# Home Team: Atlanta Hawks (ATL) - Scores: ['11', '29', '27', '27'] - Total Points: 94
# -------------------------------------------
# Date: 2021-12-05T23:00:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['30', '38', '31', '31'] - Total Points: 130
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '31', '31', '35'] - Total Points: 127
# -------------------------------------------
# Date: 2021-11-21T00:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['21', '27', '29', '28'] - Total Points: 105
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '35', '29', '26'] - Total Points: 115
# -------------------------------------------
# Date: 2022-04-13T23:00:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['23', '29', '24', '27'] - Total Points: 103
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '28', '42', '30'] - Total Points: 132
# -------------------------------------------
# Date: 2022-10-23T21:00:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['22', '37', '45', '22'] - Total Points: 126
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '25', '29', '25'] - Total Points: 109
# -------------------------------------------
# Date: 2024-03-23T23:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['28', '20', '26', '17'] - Total Points: 91
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '36', '33', '33'] - Total Points: 132
# -------------------------------------------
# Date: 2024-04-10T23:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['30', '25', '22', '38'] - Total Points: 115
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '26', '31', '22'] - Total Points: 114
# -------------------------------------------
# Date: 2023-01-22T00:30:00.000Z
# Visitor Team: Charlotte Hornets (CHA) - Scores: ['25', '24', '36', '37'] - Total Points: 122
# Home Team: Atlanta Hawks (ATL) - Scores: ['31', '34', '28', '25'] - Total Points: 118
# -------------------------------------------
# Date: 2015-11-01T19:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '18', '24', '24'] - Total Points: 94
# Home Team: Charlotte Hornets (CHA) - Scores: ['18', '21', '37', '16'] - Total Points: 92
# -------------------------------------------
# Date: 2016-01-14T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '17', '22', '26'] - Total Points: 84
# Home Team: Charlotte Hornets (CHA) - Scores: ['20', '25', '35', '27'] - Total Points: 107
# -------------------------------------------
# Date: 2016-11-19T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '17', '35', '16'] - Total Points: 96
# Home Team: Charlotte Hornets (CHA) - Scores: ['29', '19', '27', '25'] - Total Points: 100
# -------------------------------------------
# Date: 2017-03-20T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '23', '26', '22'] - Total Points: 90
# Home Team: Charlotte Hornets (CHA) - Scores: ['19', '32', '32', '22'] - Total Points: 105
# -------------------------------------------
# Date: 2017-10-20T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '28', '17', '18'] - Total Points: 91
# Home Team: Charlotte Hornets (CHA) - Scores: ['18', '31', '35', '25'] - Total Points: 109
# -------------------------------------------
# Date: 2018-01-27T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '26', '34', '24'] - Total Points: 110
# Home Team: Charlotte Hornets (CHA) - Scores: ['30', '31', '29', '31'] - Total Points: 121
# -------------------------------------------
# Date: 2018-11-07T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '29', '23', '25'] - Total Points: 102
# Home Team: Charlotte Hornets (CHA) - Scores: ['23', '28', '30', '32'] - Total Points: 113
# -------------------------------------------
# Date: 2018-11-29T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '21', '26', '19'] - Total Points: 94
# Home Team: Charlotte Hornets (CHA) - Scores: ['24', '31', '31', '22'] - Total Points: 108
# -------------------------------------------
# Date: 2019-12-08T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '27', '37', '34'] - Total Points: 122
# Home Team: Charlotte Hornets (CHA) - Scores: ['27', '26', '30', '24'] - Total Points: 107
# -------------------------------------------
# Date: 2021-01-10T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['29', '21', '26', '29'] - Total Points: 105
# Home Team: Charlotte Hornets (CHA) - Scores: ['28', '31', '28', '26'] - Total Points: 113
# -------------------------------------------
# Date: 2021-04-11T17:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '19', '23', '30'] - Total Points: 105
# Home Team: Charlotte Hornets (CHA) - Scores: ['20', '25', '32', '24'] - Total Points: 101
# -------------------------------------------
# Date: 2022-01-24T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['30', '25', '30', '28'] - Total Points: 113
# Home Team: Charlotte Hornets (CHA) - Scores: ['22', '22', '22', '25'] - Total Points: 91
# -------------------------------------------
# Date: 2022-03-16T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '34', '18', '21'] - Total Points: 106
# Home Team: Charlotte Hornets (CHA) - Scores: ['29', '33', '23', '31'] - Total Points: 116
# -------------------------------------------
# Date: 2022-12-17T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['38', '37', '23', '27'] - Total Points: 125
# Home Team: Charlotte Hornets (CHA) - Scores: ['24', '35', '33', '14'] - Total Points: 106
# -------------------------------------------
# Date: 2023-02-14T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['27', '41', '28', '42'] - Total Points: 138
# Home Team: Charlotte Hornets (CHA) - Scores: ['36', '38', '35', '35'] - Total Points: 144
# -------------------------------------------
# Date: 2023-10-25T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['29', '23', '21', '37'] - Total Points: 110
# Home Team: Charlotte Hornets (CHA) - Scores: ['25', '26', '27', '38'] - Total Points: 116
# -------------------------------------------
# Date: 2024-02-15T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['31', '24', '25', '19'] - Total Points: 99
# Home Team: Charlotte Hornets (CHA) - Scores: ['29', '32', '35', '26'] - Total Points: 122
# -------------------------------------------
# Date: 2016-01-09T22:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['19', '32', '32', '22'] - Total Points: 105
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '34', '25', '31'] - Total Points: 120
# -------------------------------------------
# Date: 2016-02-27T01:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['21', '23', '23', '21'] - Total Points: 88
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '25', '28', '24'] - Total Points: 103
# -------------------------------------------
# Date: 2016-11-10T00:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['27', '34', '27', '19'] - Total Points: 107
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '33', '26', '21'] - Total Points: 115
# -------------------------------------------
# Date: 2017-01-21T01:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['13', '23', '21', '36'] - Total Points: 93
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '30', '22', '15'] - Total Points: 102
# -------------------------------------------
# Date: 2018-01-20T22:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['29', '26', '22', '36'] - Total Points: 113
# Home Team: Atlanta Hawks (ATL) - Scores: ['21', '17', '25', '34'] - Total Points: 97
# -------------------------------------------
# Date: 2018-03-11T19:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['20', '33', '38', '38'] - Total Points: 129
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '16', '35', '37'] - Total Points: 122
# -------------------------------------------
# Date: 2018-10-27T23:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['22', '19', '26', '30'] - Total Points: 97
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '19', '19', '22'] - Total Points: 85
# -------------------------------------------
# Date: 2019-03-02T00:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['26', '31', '38', '29', '16', '7', '8', '13'] - Total Points: 168
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '27', '24', '40', '16', '7', '8', '6'] - Total Points: 161
# -------------------------------------------
# Date: 2019-11-07T00:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['33', '23', '35', '22'] - Total Points: 113
# Home Team: Atlanta Hawks (ATL) - Scores: ['19', '22', '24', '28'] - Total Points: 93
# -------------------------------------------
# Date: 2021-05-02T00:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['26', '37', '12', '22'] - Total Points: 97
# Home Team: Atlanta Hawks (ATL) - Scores: ['31', '23', '28', '26'] - Total Points: 108
# -------------------------------------------
# Date: 2021-04-10T00:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['33', '33', '18', '24'] - Total Points: 108
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '28', '33', '34'] - Total Points: 120
# -------------------------------------------
# Date: 2021-12-28T00:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['31', '38', '29', '32'] - Total Points: 130
# Home Team: Atlanta Hawks (ATL) - Scores: ['36', '27', '24', '31'] - Total Points: 118
# -------------------------------------------
# Date: 2022-03-04T00:00:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['35', '28', '29', '32'] - Total Points: 124
# Home Team: Atlanta Hawks (ATL) - Scores: ['29', '27', '34', '40'] - Total Points: 130
# -------------------------------------------
# Date: 2022-12-11T23:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['27', '23', '28', '32', '12'] - Total Points: 122
# Home Team: Atlanta Hawks (ATL) - Scores: ['22', '36', '27', '25', '13'] - Total Points: 123
# -------------------------------------------
# Date: 2022-12-22T00:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['30', '31', '20', '29'] - Total Points: 110
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '26', '26', '31'] - Total Points: 108
# -------------------------------------------
# Date: 2024-02-13T00:30:00.000Z
# Visitor Team: Chicago Bulls (CHI) - Scores: ['26', '34', '37', '39'] - Total Points: 136
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '26', '33', '34'] - Total Points: 126
# -------------------------------------------
# Date: 2016-02-11T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '25', '38', '22'] - Total Points: 113
# Home Team: Chicago Bulls (CHI) - Scores: ['29', '19', '25', '17'] - Total Points: 90
# -------------------------------------------
# Date: 2016-03-29T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['22', '30', '28', '22'] - Total Points: 102
# Home Team: Chicago Bulls (CHI) - Scores: ['31', '14', '26', '29'] - Total Points: 100
# -------------------------------------------
# Date: 2016-10-21T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '19', '24', '29'] - Total Points: 97
# Home Team: Chicago Bulls (CHI) - Scores: ['21', '18', '23', '19'] - Total Points: 81
# -------------------------------------------
# Date: 2017-01-26T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['22', '29', '27', '41'] - Total Points: 119
# Home Team: Chicago Bulls (CHI) - Scores: ['29', '30', '24', '31'] - Total Points: 114
# -------------------------------------------
# Date: 2017-04-01T21:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['21', '25', '38', '20'] - Total Points: 104
# Home Team: Chicago Bulls (CHI) - Scores: ['23', '29', '27', '27'] - Total Points: 106
# -------------------------------------------
# Date: 2017-10-27T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '19', '20', '27'] - Total Points: 86
# Home Team: Chicago Bulls (CHI) - Scores: ['18', '19', '28', '26'] - Total Points: 91
# -------------------------------------------
# Date: 2017-07-10T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['17', '28', '14', '16'] - Total Points: 75
# Home Team: Chicago Bulls (CHI) - Scores: ['14', '12', '18', '11'] - Total Points: 55
# -------------------------------------------
# Date: 2019-01-24T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['42', '24', '32', '23'] - Total Points: 121
# Home Team: Chicago Bulls (CHI) - Scores: ['25', '35', '23', '18'] - Total Points: 101
# -------------------------------------------
# Date: 2019-03-03T20:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['35', '32', '29', '27'] - Total Points: 123
# Home Team: Chicago Bulls (CHI) - Scores: ['32', '28', '31', '27'] - Total Points: 118
# -------------------------------------------
# Date: 2018-07-10T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['18', '29', '30', '24'] - Total Points: 101
# Home Team: Chicago Bulls (CHI) - Scores: ['33', '17', '21', '22'] - Total Points: 93
# -------------------------------------------
# Date: 2019-12-12T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '19', '35', '15'] - Total Points: 102
# Home Team: Chicago Bulls (CHI) - Scores: ['37', '29', '40', '30'] - Total Points: 136
# -------------------------------------------
# Date: 2019-12-29T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '24', '22', '16'] - Total Points: 81
# Home Team: Chicago Bulls (CHI) - Scores: ['35', '29', '19', '33'] - Total Points: 116
# -------------------------------------------
# Date: 2020-12-24T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['42', '41', '28', '13'] - Total Points: 124
# Home Team: Chicago Bulls (CHI) - Scores: ['29', '30', '20', '25'] - Total Points: 104
# -------------------------------------------
# Date: 2019-10-18T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '22', '22', '29'] - Total Points: 93
# Home Team: Chicago Bulls (CHI) - Scores: ['24', '27', '28', '32'] - Total Points: 111
# -------------------------------------------
# Date: 2021-12-30T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['36', '17', '34', '30'] - Total Points: 117
# Home Team: Chicago Bulls (CHI) - Scores: ['38', '36', '30', '27'] - Total Points: 131
# -------------------------------------------
# Date: 2022-02-25T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '31', '32', '26'] - Total Points: 108
# Home Team: Chicago Bulls (CHI) - Scores: ['24', '28', '30', '30'] - Total Points: 112
# -------------------------------------------
# Date: 2023-01-24T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['21', '27', '30', '22'] - Total Points: 100
# Home Team: Chicago Bulls (CHI) - Scores: ['17', '40', '21', '33'] - Total Points: 111
# -------------------------------------------
# Date: 2023-04-05T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['36', '29', '25', '33'] - Total Points: 123
# Home Team: Chicago Bulls (CHI) - Scores: ['26', '27', '27', '25'] - Total Points: 105
# -------------------------------------------
# Date: 2023-12-27T01:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['17', '39', '29', '28'] - Total Points: 113
# Home Team: Chicago Bulls (CHI) - Scores: ['28', '22', '33', '35'] - Total Points: 118
# -------------------------------------------
# Date: 2024-04-02T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['32', '29', '29', '23'] - Total Points: 113
# Home Team: Chicago Bulls (CHI) - Scores: ['30', '23', '21', '27'] - Total Points: 101
# -------------------------------------------
# Date: 2024-04-18T01:48:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['22', '45', '25', '24'] - Total Points: 116
# Home Team: Chicago Bulls (CHI) - Scores: ['40', '33', '37', '21'] - Total Points: 131
# -------------------------------------------
# Date: 2016-04-02T00:00:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['32', '23', '22', '19', '14'] - Total Points: 110
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '18', '30', '25', '12'] - Total Points: 108
# -------------------------------------------
# Date: 2016-05-06T23:00:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['31', '24', '30', '36'] - Total Points: 121
# Home Team: Atlanta Hawks (ATL) - Scores: ['28', '35', '28', '17'] - Total Points: 108
# -------------------------------------------
# Date: 2016-05-08T19:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['27', '29', '25', '19'] - Total Points: 100
# Home Team: Atlanta Hawks (ATL) - Scores: ['36', '22', '19', '22'] - Total Points: 99
# -------------------------------------------
# Date: 2016-10-10T23:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['26', '19', '28', '20'] - Total Points: 93
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '23', '20', '26'] - Total Points: 99
# -------------------------------------------
# Date: 2017-03-04T00:00:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['39', '38', '29', '29'] - Total Points: 135
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '27', '28', '42'] - Total Points: 130
# -------------------------------------------
# Date: 2017-04-09T19:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['38', '27', '28', '18', '14'] - Total Points: 125
# Home Team: Atlanta Hawks (ATL) - Scores: ['21', '25', '21', '44', '15'] - Total Points: 126
# -------------------------------------------
# Date: 2017-12-01T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['42', '21', '36', '22'] - Total Points: 121
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '32', '23', '24'] - Total Points: 114
# -------------------------------------------
# Date: 2018-02-10T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['31', '30', '36', '26'] - Total Points: 123
# Home Team: Atlanta Hawks (ATL) - Scores: ['27', '29', '26', '25'] - Total Points: 107
# -------------------------------------------
# Date: 2018-12-30T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['26', '25', '23', '34'] - Total Points: 108
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '34', '27', '27'] - Total Points: 111
# -------------------------------------------
# Date: 2021-01-03T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['25', '19', '26', '26'] - Total Points: 96
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '21', '18', '17'] - Total Points: 91
# -------------------------------------------
# Date: 2021-03-14T23:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['22', '24', '20', '16'] - Total Points: 82
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '23', '20', '31'] - Total Points: 100
# -------------------------------------------
# Date: 2022-03-31T23:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['28', '25', '22', '32'] - Total Points: 107
# Home Team: Atlanta Hawks (ATL) - Scores: ['36', '30', '34', '31'] - Total Points: 131
# -------------------------------------------
# Date: 2022-02-16T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['36', '25', '29', '26'] - Total Points: 116
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '32', '28', '30'] - Total Points: 124
# -------------------------------------------
# Date: 2021-10-06T23:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['21', '25', '22', '31'] - Total Points: 99
# Home Team: Atlanta Hawks (ATL) - Scores: ['19', '22', '27', '28'] - Total Points: 96
# -------------------------------------------
# Date: 2023-02-25T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['23', '34', '26', '36'] - Total Points: 119
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '49', '27', '28'] - Total Points: 136
# -------------------------------------------
# Date: 2023-03-28T23:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['24', '27', '33', '34'] - Total Points: 118
# Home Team: Atlanta Hawks (ATL) - Scores: ['24', '35', '35', '26'] - Total Points: 120
# -------------------------------------------
# Date: 2023-10-10T23:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['25', '20', '35', '27'] - Total Points: 107
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '31', '20', '31'] - Total Points: 108
# -------------------------------------------
# Date: 2024-01-21T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['25', '34', '34', '23'] - Total Points: 116
# Home Team: Atlanta Hawks (ATL) - Scores: ['20', '25', '25', '25'] - Total Points: 95
# -------------------------------------------
# Date: 2024-03-07T00:30:00.000Z
# Visitor Team: Cleveland Cavaliers (CLE) - Scores: ['28', '21', '40', '12'] - Total Points: 101
# Home Team: Atlanta Hawks (ATL) - Scores: ['31', '33', '23', '25'] - Total Points: 112
# -------------------------------------------
# Date: 2015-10-07T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '25', '17', '31'] - Total Points: 98
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['23', '17', '26', '30'] - Total Points: 96
# -------------------------------------------
# Date: 2015-11-22T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '23', '22', '33'] - Total Points: 97
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['27', '30', '20', '32'] - Total Points: 109
# -------------------------------------------
# Date: 2016-04-11T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '19', '30', '19'] - Total Points: 94
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['22', '29', '39', '19'] - Total Points: 109
# -------------------------------------------
# Date: 2016-05-02T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '22', '29', '23'] - Total Points: 93
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['30', '21', '23', '30'] - Total Points: 104
# -------------------------------------------
# Date: 2016-05-05T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '18', '32', '28'] - Total Points: 98
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['35', '39', '32', '17'] - Total Points: 123
# -------------------------------------------
# Date: 2016-11-09T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '33', '31', '26'] - Total Points: 110
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['20', '22', '37', '27'] - Total Points: 106
# -------------------------------------------
# Date: 2017-04-07T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['21', '31', '31', '31'] - Total Points: 114
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['19', '31', '28', '22'] - Total Points: 100
# -------------------------------------------
# Date: 2017-10-04T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '27', '28', '34'] - Total Points: 109
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['28', '22', '19', '24'] - Total Points: 93
# -------------------------------------------
# Date: 2017-11-05T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['37', '17', '37', '26'] - Total Points: 117
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['28', '17', '33', '37'] - Total Points: 115
# -------------------------------------------
# Date: 2017-12-13T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['31', '17', '29', '37'] - Total Points: 114
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['31', '31', '32', '29'] - Total Points: 123
# -------------------------------------------
# Date: 2018-10-21T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '40', '28', '41'] - Total Points: 133
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['34', '26', '26', '25'] - Total Points: 111
# -------------------------------------------
# Date: 2018-10-30T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['31', '26', '30', '27'] - Total Points: 114
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['35', '23', '41', '37'] - Total Points: 136
# -------------------------------------------
# Date: 2019-12-24T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['32', '32', '30', '24'] - Total Points: 118
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['42', '29', '23', '27'] - Total Points: 121
# -------------------------------------------
# Date: 2020-02-13T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '29', '32', '25'] - Total Points: 105
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['33', '32', '33', '29'] - Total Points: 127
# -------------------------------------------
# Date: 2021-02-24T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['27', '28', '29', '27'] - Total Points: 111
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['28', '30', '26', '28'] - Total Points: 112
# -------------------------------------------
# Date: 2022-01-01T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '26', '40', '30'] - Total Points: 121
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['32', '34', '22', '30'] - Total Points: 118
# -------------------------------------------
# Date: 2021-10-23T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['27', '28', '17', '23'] - Total Points: 95
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['24', '28', '31', '18'] - Total Points: 101
# -------------------------------------------
# Date: 2022-04-15T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '26', '33', '23'] - Total Points: 107
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['36', '25', '23', '17'] - Total Points: 101
# -------------------------------------------
# Date: 2022-10-12T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '17', '31', '27'] - Total Points: 99
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['19', '32', '24', '30'] - Total Points: 105
# -------------------------------------------
# Date: 2022-11-22T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '33', '23', '20'] - Total Points: 102
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['38', '26', '21', '29'] - Total Points: 114
# -------------------------------------------
# Date: 2023-11-29T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '28', '29', '15'] - Total Points: 105
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['29', '35', '38', '26'] - Total Points: 128
# -------------------------------------------
# Date: 2023-12-17T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '24', '29', '38'] - Total Points: 119
# Home Team: Cleveland Cavaliers (CLE) - Scores: ['41', '29', '22', '35'] - Total Points: 127
# -------------------------------------------
# Date: 2016-02-02T01:00:00.000Z
# Visitor Team: Dallas Mavericks (DAL) - Scores: ['15', '31', '27', '24'] - Total Points: 97
# Home Team: Atlanta Hawks (ATL) - Scores: ['27', '26', '33', '26'] - Total Points: 112
# -------------------------------------------
# ...
# Date: 2020-03-04T03:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['23', '26', '46', '31'] - Total Points: 126
# Home Team: Sacramento Kings (SAC) - Scores: ['39', '37', '19', '38'] - Total Points: 133
# -------------------------------------------
# Date: 2021-04-15T02:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['42', '28', '23', '30'] - Total Points: 123
# Home Team: Sacramento Kings (SAC) - Scores: ['31', '29', '23', '28'] - Total Points: 111
# -------------------------------------------
# Date: 2021-12-16T03:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['32', '25', '32', '16'] - Total Points: 105
# Home Team: Sacramento Kings (SAC) - Scores: ['27', '29', '28', '35'] - Total Points: 119
# -------------------------------------------
# Date: 2022-12-24T03:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['28', '40', '34', '23'] - Total Points: 125
# Home Team: Sacramento Kings (SAC) - Scores: ['27', '23', '33', '28'] - Total Points: 111
# -------------------------------------------
# Date: 2023-12-19T03:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['31', '25', '35', '40'] - Total Points: 131
# Home Team: Sacramento Kings (SAC) - Scores: ['27', '39', '46', '31'] - Total Points: 143
# -------------------------------------------
# Date: 2015-12-22T00:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['35', '24', '25', '15'] - Total Points: 99
# Home Team: Washington Wizards (WAS) - Scores: ['34', '29', '21', '29'] - Total Points: 113
# -------------------------------------------
# Date: 2016-11-29T00:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['19', '34', '19', '20', '3'] - Total Points: 95
# Home Team: Washington Wizards (WAS) - Scores: ['25', '25', '24', '18', '9'] - Total Points: 101
# -------------------------------------------
# Date: 2017-11-14T00:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['32', '19', '20', '21'] - Total Points: 92
# Home Team: Washington Wizards (WAS) - Scores: ['25', '32', '29', '24'] - Total Points: 110
# -------------------------------------------
# Date: 2019-03-11T23:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['20', '40', '21', '34'] - Total Points: 115
# Home Team: Washington Wizards (WAS) - Scores: ['28', '31', '31', '31'] - Total Points: 121
# -------------------------------------------
# Date: 2019-11-24T23:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['24', '33', '33', '23'] - Total Points: 113
# Home Team: Washington Wizards (WAS) - Scores: ['27', '30', '28', '21'] - Total Points: 106
# -------------------------------------------
# Date: 2021-03-17T23:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['34', '32', '36', '19'] - Total Points: 121
# Home Team: Washington Wizards (WAS) - Scores: ['38', '28', '27', '26'] - Total Points: 119
# -------------------------------------------
# Date: 2022-02-13T00:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['24', '35', '33', '31'] - Total Points: 123
# Home Team: Washington Wizards (WAS) - Scores: ['29', '36', '23', '22'] - Total Points: 110
# -------------------------------------------
# Date: 2024-03-21T23:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['27', '27', '22', '26'] - Total Points: 102
# Home Team: Washington Wizards (WAS) - Scores: ['35', '21', '28', '25'] - Total Points: 109
# -------------------------------------------
# Date: 2023-03-19T00:00:00.000Z
# Visitor Team: Sacramento Kings (SAC) - Scores: ['37', '34', '33', '28'] - Total Points: 132
# Home Team: Washington Wizards (WAS) - Scores: ['33', '27', '32', '26'] - Total Points: 118
# -------------------------------------------
# Date: 2015-10-23T23:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['28', '17', '19', '18'] - Total Points: 82
# Home Team: Toronto Raptors (TOR) - Scores: ['21', '25', '29', '17'] - Total Points: 92
# -------------------------------------------
# Date: 2015-12-31T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['27', '14', '24', '26'] - Total Points: 91
# Home Team: Toronto Raptors (TOR) - Scores: ['28', '24', '25', '17'] - Total Points: 94
# -------------------------------------------
# Date: 2016-01-27T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['18', '32', '20', '19'] - Total Points: 89
# Home Team: Toronto Raptors (TOR) - Scores: ['24', '29', '24', '29'] - Total Points: 106
# -------------------------------------------
# Date: 2017-03-02T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['24', '38', '20', '23'] - Total Points: 105
# Home Team: Toronto Raptors (TOR) - Scores: ['26', '20', '14', '36'] - Total Points: 96
# -------------------------------------------
# Date: 2017-11-05T23:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['32', '30', '22', '23'] - Total Points: 107
# Home Team: Toronto Raptors (TOR) - Scores: ['17', '29', '30', '20'] - Total Points: 96
# -------------------------------------------
# Date: 2017-11-19T20:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['28', '27', '21', '15'] - Total Points: 91
# Home Team: Toronto Raptors (TOR) - Scores: ['28', '32', '19', '21'] - Total Points: 100
# -------------------------------------------
# Date: 2018-04-14T21:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['23', '36', '26', '21'] - Total Points: 106
# Home Team: Toronto Raptors (TOR) - Scores: ['28', '27', '31', '28'] - Total Points: 114
# -------------------------------------------
# Date: 2018-04-17T23:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['27', '31', '32', '29'] - Total Points: 119
# Home Team: Toronto Raptors (TOR) - Scores: ['44', '32', '24', '30'] - Total Points: 130
# -------------------------------------------
# Date: 2018-04-25T23:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['24', '23', '31', '20'] - Total Points: 98
# Home Team: Toronto Raptors (TOR) - Scores: ['23', '25', '31', '29'] - Total Points: 108
# -------------------------------------------
# Date: 2018-11-24T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['26', '36', '25', '20'] - Total Points: 107
# Home Team: Toronto Raptors (TOR) - Scores: ['38', '32', '31', '24'] - Total Points: 125
# -------------------------------------------
# Date: 2019-02-14T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['26', '39', '28', '27'] - Total Points: 120
# Home Team: Toronto Raptors (TOR) - Scores: ['30', '29', '44', '26'] - Total Points: 129
# -------------------------------------------
# Date: 2019-12-21T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['23', '29', '33', '33'] - Total Points: 118
# Home Team: Toronto Raptors (TOR) - Scores: ['40', '28', '28', '26'] - Total Points: 122
# -------------------------------------------
# Date: 2020-01-18T00:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['26', '25', '25', '35'] - Total Points: 111
# Home Team: Toronto Raptors (TOR) - Scores: ['38', '27', '35', '40'] - Total Points: 140
# -------------------------------------------
# Date: 2021-05-06T23:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['31', '20', '31', '33', '16'] - Total Points: 131
# Home Team: Toronto Raptors (TOR) - Scores: ['33', '27', '26', '29', '14'] - Total Points: 129
# -------------------------------------------
# Date: 2021-10-20T23:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['26', '31', '24', '17'] - Total Points: 98
# Home Team: Toronto Raptors (TOR) - Scores: ['18', '19', '22', '24'] - Total Points: 83
# -------------------------------------------
# Date: 2021-04-05T23:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['28', '33', '25', '15'] - Total Points: 101
# Home Team: Toronto Raptors (TOR) - Scores: ['19', '32', '24', '28'] - Total Points: 103
# -------------------------------------------
# Date: 2021-12-05T23:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['12', '30', '26', '22'] - Total Points: 90
# Home Team: Toronto Raptors (TOR) - Scores: ['23', '40', '21', '18'] - Total Points: 102
# -------------------------------------------
# Date: 2023-03-26T22:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['21', '25', '38', '20'] - Total Points: 104
# Home Team: Toronto Raptors (TOR) - Scores: ['37', '26', '24', '27'] - Total Points: 114
# -------------------------------------------
# Date: 2023-10-20T23:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['24', '28', '22', '24'] - Total Points: 98
# Home Team: Toronto Raptors (TOR) - Scores: ['31', '27', '43', '33'] - Total Points: 134
# -------------------------------------------
# Date: 2023-11-14T00:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['32', '32', '27', '16'] - Total Points: 107
# Home Team: Toronto Raptors (TOR) - Scores: ['25', '20', '36', '30'] - Total Points: 111
# -------------------------------------------
# Date: 2024-04-07T22:00:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['17', '33', '37', '35'] - Total Points: 122
# Home Team: Toronto Raptors (TOR) - Scores: ['42', '21', '36', '31'] - Total Points: 130
# -------------------------------------------
# Date: 2024-10-06T23:30:00.000Z
# Visitor Team: Washington Wizards (WAS) - Scores: ['16', '22', '36', '24'] - Total Points: 98
# Home Team: Toronto Raptors (TOR) - Scores: ['34', '22', '35', '34'] - Total Points: 125
# -------------------------------------------
# Date: 2015-11-29T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['16', '23', '23', '22'] - Total Points: 84
# Home Team: Washington Wizards (WAS) - Scores: ['23', '22', '23', '14'] - Total Points: 82
# -------------------------------------------
# Date: 2016-01-09T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['18', '29', '26', '24'] - Total Points: 97
# Home Team: Washington Wizards (WAS) - Scores: ['26', '21', '14', '27'] - Total Points: 88
# -------------------------------------------
# Date: 2016-10-21T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['23', '33', '10', '16'] - Total Points: 82
# Home Team: Washington Wizards (WAS) - Scores: ['39', '26', '28', '26'] - Total Points: 119
# -------------------------------------------
# Date: 2016-11-02T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['27', '27', '30', '29'] - Total Points: 113
# Home Team: Washington Wizards (WAS) - Scores: ['29', '27', '19', '28'] - Total Points: 103
# -------------------------------------------
# Date: 2017-03-04T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['35', '27', '17', '35'] - Total Points: 114
# Home Team: Washington Wizards (WAS) - Scores: ['27', '26', '25', '28'] - Total Points: 106
# -------------------------------------------
# Date: 2018-02-02T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['34', '28', '25', '32'] - Total Points: 119
# Home Team: Washington Wizards (WAS) - Scores: ['27', '28', '33', '34'] - Total Points: 122
# -------------------------------------------
# Date: 2018-03-03T01:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['19', '32', '26', '25'] - Total Points: 102
# Home Team: Washington Wizards (WAS) - Scores: ['27', '20', '27', '21'] - Total Points: 95
# -------------------------------------------
# Date: 2018-04-21T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['29', '32', '21', '21'] - Total Points: 103
# Home Team: Washington Wizards (WAS) - Scores: ['30', '39', '32', '21'] - Total Points: 122
# -------------------------------------------
# Date: 2018-04-22T22:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['30', '21', '29', '18'] - Total Points: 98
# Home Team: Washington Wizards (WAS) - Scores: ['22', '18', '40', '26'] - Total Points: 106
# -------------------------------------------
# Date: 2018-04-27T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['20', '30', '23', '29'] - Total Points: 102
# Home Team: Washington Wizards (WAS) - Scores: ['30', '23', '25', '14'] - Total Points: 92
# -------------------------------------------
# Date: 2018-10-20T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['24', '33', '33', '27'] - Total Points: 117
# Home Team: Washington Wizards (WAS) - Scores: ['22', '32', '28', '31'] - Total Points: 113
# -------------------------------------------
# Date: 2019-01-13T18:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['36', '25', '37', '26', '7', '9'] - Total Points: 140
# Home Team: Washington Wizards (WAS) - Scores: ['21', '29', '34', '40', '7', '7'] - Total Points: 138
# -------------------------------------------
# Date: 2021-02-11T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['40', '34', '29', '34'] - Total Points: 137
# Home Team: Washington Wizards (WAS) - Scores: ['28', '33', '32', '22'] - Total Points: 115
# -------------------------------------------
# Date: 2021-11-03T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['29', '30', '27', '23'] - Total Points: 109
# Home Team: Washington Wizards (WAS) - Scores: ['29', '19', '29', '23'] - Total Points: 100
# -------------------------------------------
# Date: 2022-01-22T01:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['20', '35', '36', '18'] - Total Points: 109
# Home Team: Washington Wizards (WAS) - Scores: ['30', '24', '23', '28'] - Total Points: 105
# -------------------------------------------
# Date: 2021-10-12T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['26', '32', '23', '32'] - Total Points: 113
# Home Team: Washington Wizards (WAS) - Scores: ['30', '28', '31', '19'] - Total Points: 108
# -------------------------------------------
# Date: 2023-03-03T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['20', '30', '28', '30'] - Total Points: 108
# Home Team: Washington Wizards (WAS) - Scores: ['24', '35', '30', '30'] - Total Points: 119
# -------------------------------------------
# Date: 2023-03-04T22:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['26', '27', '33', '19', '11'] - Total Points: 116
# Home Team: Washington Wizards (WAS) - Scores: ['30', '23', '26', '26', '4'] - Total Points: 109
# -------------------------------------------
# Date: 2023-12-28T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['31', '28', '38', '35'] - Total Points: 132
# Home Team: Washington Wizards (WAS) - Scores: ['25', '25', '31', '21'] - Total Points: 102
# -------------------------------------------
# Date: 2024-03-24T00:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['25', '23', '33', '28'] - Total Points: 109
# Home Team: Washington Wizards (WAS) - Scores: ['23', '28', '26', '35'] - Total Points: 112
# -------------------------------------------
# Date: 2024-10-11T23:00:00.000Z
# Visitor Team: Toronto Raptors (TOR) - Scores: ['25', '22', '32', '16'] - Total Points: 95
# Home Team: Washington Wizards (WAS) - Scores: ['18', '30', '34', '31'] - Total Points: 113
# -------------------------------------------
#                           date          visitor                home  \
# 0     2015-11-25T01:00:00.000Z   Boston Celtics       Atlanta Hawks
# 1     2016-04-09T23:30:00.000Z   Boston Celtics       Atlanta Hawks
# 2     2016-04-16T23:00:00.000Z   Boston Celtics       Atlanta Hawks
# 3     2016-04-19T23:00:00.000Z   Boston Celtics       Atlanta Hawks
# 4     2016-04-27T00:30:00.000Z   Boston Celtics       Atlanta Hawks
# ...                        ...              ...                 ...
# 3390  2023-12-28T00:00:00.000Z  Toronto Raptors  Washington Wizards
# 3391  2024-03-24T00:00:00.000Z  Toronto Raptors  Washington Wizards
# 3392  2024-10-11T23:00:00.000Z  Toronto Raptors  Washington Wizards
# 3393  2025-01-30T00:00:00.000Z  Toronto Raptors  Washington Wizards
# 3394  2025-03-24T23:00:00.000Z  Toronto Raptors  Washington Wizards
#
#       visitor_points  home_points
# 0               97.0        121.0
# 1              107.0        118.0
# 2              101.0        102.0
# 3               72.0         89.0
# 4               83.0        110.0
# ...              ...          ...
# 3390           132.0        102.0
# 3391           109.0        112.0
# 3392            95.0        113.0
# 3393             NaN          NaN
# 3394             NaN          NaN
#
# [3395 rows x 5 columns]
