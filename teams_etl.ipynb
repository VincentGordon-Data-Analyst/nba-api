# %%
import requests
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import time
import datetime as dt

print('Imports completed!')
# Out:
# Imports completed!

# %% [markdown]
# # TEAMS

# %%
url = "https://api-nba-v1.p.rapidapi.com/teams"
headers = {
	"x-rapidapi-key": "dda6cf782dmshebe3119a485b548p154863jsn7c9c31f1e7a7",
	"x-rapidapi-host": "api-nba-v1.p.rapidapi.com"
}

# Extract from url and header parameters
def extract_data(api_url, headers):
    response = requests.get(api_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"API request failed with status code: {response.status_code}")

# Clean the data
def transform_data(raw_data):
    # ID's to not be included
    exclude_ids = {37, 34, 39, 102, 103, 42, 35, 36, 49}

    # Gather Data for Teams
    teams = [
        {
            'team_id': row['id'],
            'team_code': row['code'],
            'team_name': row['name']
        }
        for row in raw_data['response']
        if 'leagues' in row and 'standard' in row['leagues']
        and row['leagues']['standard']['division'] is not None
        and row['id'] not in exclude_ids
    ]
    
    teams_df = pd.DataFrame(teams)
    return teams_df

# Load data into a table
def load_data(df, table_name, connection_string):
    engine = create_engine(connection_string)
    df.to_sql(table_name, engine, if_exists='replace', index=False)
    print(f'Data has been loaded and added to the {table_name} database')

# %%
# Run data pipeline
def run_pipeline():
    raw_data = extract_data(url, headers)
    clean_data = transform_data(raw_data)
    connection_string = 'sqlite:///teams_data.db'
    load_data(clean_data, 'teams', connection_string)
    
run_pipeline()
# Out:
# Data has been loaded and added to the teams database

# %% [markdown]
# # GAME SCORES

# %%
import pandas as pd
from sqlalchemy import create_engine

def read_data(connection_string):
    engine = create_engine(connection_string)
    query = "SELECT * FROM teams"
    df = pd.read_sql(query, con=engine)
    return df

# Read the data back from the database
connection_string = 'sqlite:///teams_data.db'
teams_data = read_data(connection_string)

# Display the data
teams_data.head()
# Out:
#    team_id team_code          team_name
# 0        1       ATL      Atlanta Hawks
# 1        2       BOS     Boston Celtics
# 2        4       BKN      Brooklyn Nets
# 3        5       CHA  Charlotte Hornets
# 4        6       CHI      Chicago Bulls

# %%
from itertools import permutations 
import time

url = "https://api-nba-v1.p.rapidapi.com/games"
headers = {
	"x-rapidapi-key": "dda6cf782dmshebe3119a485b548p154863jsn7c9c31f1e7a7",
	"x-rapidapi-host": "api-nba-v1.p.rapidapi.com"
}

# Get a list of all team ids (only take for 2 for example)
team_ids = teams_data['team_id'].values[:3]

def game_matches(team_ids, url, headers):
    # Use team ids to make game matches
    matchups = list(permutations(team_ids, 2))
    
    # Filter games where (id1, id2) != (id2, id1)
    unique_matchups = []
    for game in matchups:
        if game[1] > game[0]:
            unique_matchups.append((game[0], game[1]))
        else:
            continue
    
    # Create an array to store the information
    response_arr = []
    for game in unique_matchups:
        querystring = {"h2h":f"{game[0]}-{game[1]}"}
        print(f"Gathering data for matchup {game[0]}-{game[1]}")
        
        # Make the API request
        response = requests.get(url, headers=headers, params=querystring)
        
        # Check if the response is successful:
        if response.status_code == 200:
            game_data = response.json()
            response_arr.append(game_data)
        else:
            print(f"Failed to gather data for {game[0]}-{game[1]}. Status code: {response.status_code}")
        
        # Avoid hitting rate limits
        time.sleep(1)

    # Display gathered data
    return response_arr

results = game_matches(team_ids=team_ids, url=url, headers=headers)
# Out:
# Gathering data for matchup 1-2
# Gathering data for matchup 1-4
# Gathering data for matchup 2-4

# %%
for info in results:
    for game in info['response']:
        # Extract date of the game
        date = game.get('date', {}).get('start','N/A')
        
        # Extract teams info
        visitor = game.get('teams', {}).get('visitors', {}).get('name', 'Unknown')
        home = game.get('teams', {}).get('home', {}).get('name', 'Unknown')
     
        visitor_code = game.get('teams', {}).get('visitors', {}).get('code', 'N/A')
        home_code = game.get('teams', {}).get('home', {}).get('code', 'N/A') 
        
        
        # Extract scores
        visitor_scores = game.get('scores', {}).get('visitors', {}).get('linescore', 'No scores')
        home_scores = game.get('scores', {}).get('home', {}).get('linescore', 'No scores')
        
        
        # Display data
        print(f"Date: {date}")
        print(f"Visitor Team: {visitor} ({visitor_code}) - Scores: {visitor_scores}")
        print(f"Home Team: {home} ({home_code}) - Scores: {home_scores}")
        print('-------------------------------------------')
# Out:
# Date: 2015-11-25T01:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '20', '25', '24']
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '24', '24', '40']
# -------------------------------------------
# Date: 2016-04-09T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['32', '39', '20', '16']
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '33', '26', '25']
# -------------------------------------------
# Date: 2016-04-16T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['19', '15', '31', '36']
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '21', '21', '30']
# -------------------------------------------
# Date: 2016-04-19T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['7', '21', '18', '26']
# Home Team: Atlanta Hawks (ATL) - Scores: ['24', '19', '18', '28']
# -------------------------------------------
# Date: 2016-04-27T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['20', '19', '23', '21']
# Home Team: Atlanta Hawks (ATL) - Scores: ['15', '32', '42', '21']
# -------------------------------------------
# Date: 2017-01-14T01:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '20', '30', '25']
# Home Team: Atlanta Hawks (ATL) - Scores: ['18', '26', '21', '36']
# -------------------------------------------
# Date: 2017-04-07T00:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['24', '31', '34', '27']
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '39', '28', '24']
# -------------------------------------------
# Date: 2017-11-07T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['26', '28', '28', '28']
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '29', '21', '32']
# -------------------------------------------
# Date: 2017-11-19T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['20', '24', '36', '30']
# Home Team: Atlanta Hawks (ATL) - Scores: ['35', '15', '27', '22']
# -------------------------------------------
# Date: 2018-11-24T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['45', '16', '21', '32']
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '22', '19', '32']
# -------------------------------------------
# Date: 2019-01-20T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '32', '23', '30']
# Home Team: Atlanta Hawks (ATL) - Scores: ['36', '31', '22', '16']
# -------------------------------------------
# Date: 2020-02-04T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '32', '35', '28']
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '28', '22', '31']
# -------------------------------------------
# Date: 2021-02-25T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['27', '22', '29', '34']
# Home Team: Atlanta Hawks (ATL) - Scores: ['40', '32', '27', '28']
# -------------------------------------------
# Date: 2021-08-08T20:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: []
# Home Team: Atlanta Hawks (ATL) - Scores: []
# -------------------------------------------
# Date: 2021-11-18T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['29', '20', '28', '22']
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '28', '33', '19']
# -------------------------------------------
# Date: 2022-01-29T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['20', '27', '30', '15']
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '30', '18', '28']
# -------------------------------------------
# Date: 2022-11-17T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['30', '32', '35', '29']
# Home Team: Atlanta Hawks (ATL) - Scores: ['18', '35', '25', '23']
# -------------------------------------------
# Date: 2023-04-21T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['37', '30', '26', '29']
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '41', '26', '30']
# -------------------------------------------
# Date: 2023-04-23T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '30', '27', '37']
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '28', '34', '34']
# -------------------------------------------
# Date: 2023-04-28T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '33', '30', '30']
# Home Team: Atlanta Hawks (ATL) - Scores: ['34', '33', '33', '20']
# -------------------------------------------
# Date: 2024-03-25T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['44', '30', '22', '22']
# Home Team: Atlanta Hawks (ATL) - Scores: ['22', '34', '34', '30']
# -------------------------------------------
# Date: 2024-03-28T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['29', '34', '27', '22', '10']
# Home Team: Atlanta Hawks (ATL) - Scores: ['28', '31', '30', '23', '11']
# -------------------------------------------
# Date: 2023-03-12T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['37', '34', '30', '33']
# Home Team: Atlanta Hawks (ATL) - Scores: ['38', '23', '28', '36']
# -------------------------------------------
# Date: 2024-11-05T00:45:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: []
# Home Team: Atlanta Hawks (ATL) - Scores: []
# -------------------------------------------
# Date: 2015-11-14T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '19', '24', '24']
# Home Team: Boston Celtics (BOS) - Scores: ['23', '22', '35', '26']
# -------------------------------------------
# Date: 2015-12-19T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '23', '29', '38']
# Home Team: Boston Celtics (BOS) - Scores: ['25', '18', '30', '28']
# -------------------------------------------
# Date: 2016-04-23T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '25', '33', '25']
# Home Team: Boston Celtics (BOS) - Scores: ['37', '20', '22', '32']
# -------------------------------------------
# Date: 2016-04-24T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['21', '27', '25', '19', '3']
# Home Team: Boston Celtics (BOS) - Scores: ['24', '22', '24', '22', '12']
# -------------------------------------------
# Date: 2016-04-29T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['20', '21', '39', '24']
# Home Team: Boston Celtics (BOS) - Scores: ['17', '16', '26', '33']
# -------------------------------------------
# Date: 2017-02-28T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '27', '33', '30']
# Home Team: Boston Celtics (BOS) - Scores: ['24', '23', '24', '27']
# -------------------------------------------
# Date: 2018-02-03T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['32', '23', '20', '35']
# Home Team: Boston Celtics (BOS) - Scores: ['26', '27', '41', '25']
# -------------------------------------------
# Date: 2018-04-08T17:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '25', '27', '36']
# Home Team: Boston Celtics (BOS) - Scores: ['31', '27', '24', '24']
# -------------------------------------------
# Date: 2018-12-15T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '37', '26', '26']
# Home Team: Boston Celtics (BOS) - Scores: ['42', '25', '41', '21']
# -------------------------------------------
# Date: 2019-03-16T16:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['36', '26', '30', '28']
# Home Team: Boston Celtics (BOS) - Scores: ['43', '31', '31', '24']
# -------------------------------------------
# Date: 2020-01-04T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['32', '23', '25', '26']
# Home Team: Boston Celtics (BOS) - Scores: ['19', '34', '29', '27']
# -------------------------------------------
# Date: 2020-02-08T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '29', '18', '34']
# Home Team: Boston Celtics (BOS) - Scores: ['28', '26', '33', '25']
# -------------------------------------------
# Date: 2021-02-20T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['22', '19', '32', '36']
# Home Team: Boston Celtics (BOS) - Scores: ['33', '33', '32', '23']
# -------------------------------------------
# Date: 2021-02-18T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '29', '28', '32']
# Home Team: Boston Celtics (BOS) - Scores: ['35', '21', '25', '33']
# -------------------------------------------
# Date: 2022-02-13T19:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '27', '23', '17']
# Home Team: Boston Celtics (BOS) - Scores: ['17', '28', '42', '18']
# -------------------------------------------
# Date: 2022-03-02T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '37', '13', '20']
# Home Team: Boston Celtics (BOS) - Scores: ['19', '32', '31', '25']
# -------------------------------------------
# Date: 2023-04-09T17:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['31', '33', '26', '24']
# Home Team: Boston Celtics (BOS) - Scores: ['29', '32', '39', '20']
# -------------------------------------------
# Date: 2023-04-15T19:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '25', '31', '24']
# Home Team: Boston Celtics (BOS) - Scores: ['29', '45', '20', '18']
# -------------------------------------------
# Date: 2023-04-18T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '24', '32', '25']
# Home Team: Boston Celtics (BOS) - Scores: ['28', '33', '29', '29']
# -------------------------------------------
# Date: 2023-04-25T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['30', '28', '24', '37']
# Home Team: Boston Celtics (BOS) - Scores: ['27', '39', '26', '25']
# -------------------------------------------
# Date: 2023-11-26T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['26', '27', '29', '21']
# Home Team: Boston Celtics (BOS) - Scores: ['33', '36', '21', '23']
# -------------------------------------------
# Date: 2024-02-08T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['37', '30', '23', '27']
# Home Team: Boston Celtics (BOS) - Scores: ['35', '36', '24', '30']
# -------------------------------------------
# Date: 2024-11-13T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: []
# Home Team: Boston Celtics (BOS) - Scores: []
# -------------------------------------------
# Date: 2025-01-19T00:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: []
# Home Team: Boston Celtics (BOS) - Scores: []
# -------------------------------------------
# Date: 2015-11-05T01:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['17', '26', '27', '17']
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '18', '31', '29']
# -------------------------------------------
# Date: 2016-01-17T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['23', '25', '20', '18']
# Home Team: Atlanta Hawks (ATL) - Scores: ['27', '28', '29', '30']
# -------------------------------------------
# Date: 2017-03-09T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['27', '23', '30', '25']
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '23', '35', '29']
# -------------------------------------------
# Date: 2017-03-26T17:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['32', '23', '23', '29']
# Home Team: Atlanta Hawks (ATL) - Scores: ['20', '28', '20', '24']
# -------------------------------------------
# Date: 2017-12-05T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '20', '31', '26']
# Home Team: Atlanta Hawks (ATL) - Scores: ['32', '22', '15', '21']
# -------------------------------------------
# Date: 2018-01-13T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['25', '28', '21', '36']
# Home Team: Atlanta Hawks (ATL) - Scores: ['25', '25', '24', '31']
# -------------------------------------------
# Date: 2017-07-08T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['23', '19', '22', '11']
# Home Team: Atlanta Hawks (ATL) - Scores: ['21', '10', '17', '24']
# -------------------------------------------
# Date: 2019-03-10T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '30', '27', '31']
# Home Team: Atlanta Hawks (ATL) - Scores: ['23', '24', '30', '35']
# -------------------------------------------
# Date: 2019-12-05T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['22', '34', '35', '39']
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '21', '35', '36']
# -------------------------------------------
# Date: 2020-02-29T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['36', '26', '36', '20']
# Home Team: Atlanta Hawks (ATL) - Scores: ['29', '39', '40', '33']
# -------------------------------------------
# Date: 2021-01-28T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '29', '28', '33', '16']
# Home Team: Atlanta Hawks (ATL) - Scores: ['27', '28', '32', '29', '12']
# -------------------------------------------
# Date: 2021-12-11T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '26', '37', '24']
# Home Team: Atlanta Hawks (ATL) - Scores: ['26', '29', '36', '14']
# -------------------------------------------
# Date: 2022-04-02T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['30', '20', '37', '28']
# Home Team: Atlanta Hawks (ATL) - Scores: ['28', '37', '29', '28']
# -------------------------------------------
# Date: 2022-12-29T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['31', '25', '27', '25']
# Home Team: Atlanta Hawks (ATL) - Scores: ['30', '33', '17', '27']
# -------------------------------------------
# Date: 2023-02-26T20:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['29', '28', '37', '33']
# Home Team: Atlanta Hawks (ATL) - Scores: ['37', '27', '33', '32']
# -------------------------------------------
# Date: 2023-11-23T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '34', '28', '36', '14']
# Home Team: Atlanta Hawks (ATL) - Scores: ['45', '32', '23', '31', '16']
# -------------------------------------------
# Date: 2023-12-07T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['31', '22', '28', '33']
# Home Team: Atlanta Hawks (ATL) - Scores: ['33', '23', '26', '31']
# -------------------------------------------
# Date: 2024-10-23T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: []
# Home Team: Atlanta Hawks (ATL) - Scores: []
# -------------------------------------------
# Date: 2015-11-18T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['19', '27', '22', '20']
# Home Team: Brooklyn Nets (BKN) - Scores: ['17', '28', '27', '18']
# -------------------------------------------
# Date: 2017-01-11T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['35', '26', '25', '31']
# Home Team: Brooklyn Nets (BKN) - Scores: ['29', '14', '27', '27']
# -------------------------------------------
# Date: 2017-04-02T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['24', '19', '18', '21']
# Home Team: Brooklyn Nets (BKN) - Scores: ['29', '17', '24', '21']
# -------------------------------------------
# Date: 2017-10-22T19:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '28', '24', '27']
# Home Team: Brooklyn Nets (BKN) - Scores: ['19', '37', '35', '25']
# -------------------------------------------
# Date: 2017-12-02T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['25', '29', '27', '33']
# Home Team: Brooklyn Nets (BKN) - Scores: ['22', '23', '30', '27']
# -------------------------------------------
# Date: 2018-12-16T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['23', '43', '30', '31']
# Home Team: Brooklyn Nets (BKN) - Scores: ['42', '30', '39', '33']
# -------------------------------------------
# Date: 2019-01-10T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['38', '19', '23', '20']
# Home Team: Brooklyn Nets (BKN) - Scores: ['23', '28', '35', '30']
# -------------------------------------------
# Date: 2019-12-21T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['34', '39', '25', '14']
# Home Team: Brooklyn Nets (BKN) - Scores: ['34', '26', '25', '37']
# -------------------------------------------
# Date: 2020-01-12T23:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['16', '30', '20', '20']
# Home Team: Brooklyn Nets (BKN) - Scores: ['37', '33', '22', '16']
# -------------------------------------------
# Date: 2020-12-31T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['41', '27', '36', '37']
# Home Team: Brooklyn Nets (BKN) - Scores: ['38', '29', '35', '43']
# -------------------------------------------
# Date: 2021-01-02T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['29', '32', '28', '25']
# Home Team: Brooklyn Nets (BKN) - Scores: ['23', '29', '21', '23']
# -------------------------------------------
# Date: 2021-11-03T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '31', '20', '29']
# Home Team: Brooklyn Nets (BKN) - Scores: ['35', '26', '34', '22']
# -------------------------------------------
# Date: 2022-12-10T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['30', '34', '26', '26']
# Home Team: Brooklyn Nets (BKN) - Scores: ['36', '32', '28', '24']
# -------------------------------------------
# Date: 2023-03-31T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['33', '22', '24', '28']
# Home Team: Brooklyn Nets (BKN) - Scores: ['25', '34', '42', '23']
# -------------------------------------------
# Date: 2024-03-01T00:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['16', '34', '25', '22']
# Home Team: Brooklyn Nets (BKN) - Scores: ['34', '22', '38', '30']
# -------------------------------------------
# Date: 2024-03-02T20:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: ['28', '34', '18', '22']
# Home Team: Brooklyn Nets (BKN) - Scores: ['21', '39', '30', '24']
# -------------------------------------------
# Date: 2025-03-16T22:00:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: []
# Home Team: Brooklyn Nets (BKN) - Scores: []
# -------------------------------------------
# Date: 2025-04-10T23:30:00.000Z
# Visitor Team: Atlanta Hawks (ATL) - Scores: []
# Home Team: Brooklyn Nets (BKN) - Scores: []
# -------------------------------------------
# Date: 2015-10-14T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['28', '26', '24', '31']
# Home Team: Brooklyn Nets (BKN) - Scores: ['21', '22', '28', '34']
# -------------------------------------------
# Date: 2015-11-22T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['19', '23', '36', '23']
# Home Team: Brooklyn Nets (BKN) - Scores: ['24', '35', '27', '25']
# -------------------------------------------
# Date: 2016-01-05T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['37', '19', '23', '24']
# Home Team: Brooklyn Nets (BKN) - Scores: ['22', '20', '26', '26']
# -------------------------------------------
# Date: 2016-10-13T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['23', '24', '30', '23']
# Home Team: Brooklyn Nets (BKN) - Scores: ['27', '18', '24', '28']
# -------------------------------------------
# Date: 2016-11-24T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['30', '21', '28', '32']
# Home Team: Brooklyn Nets (BKN) - Scores: ['16', '33', '17', '26']
# -------------------------------------------
# Date: 2017-03-17T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['21', '24', '26', '27']
# Home Team: Brooklyn Nets (BKN) - Scores: ['16', '21', '28', '30']
# -------------------------------------------
# Date: 2017-11-15T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['30', '22', '28', '29']
# Home Team: Brooklyn Nets (BKN) - Scores: ['21', '31', '19', '31']
# -------------------------------------------
# Date: 2018-01-06T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['16', '23', '25', '23']
# Home Team: Brooklyn Nets (BKN) - Scores: ['22', '19', '20', '24']
# -------------------------------------------
# Date: 2019-01-15T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['25', '20', '21', '36']
# Home Team: Brooklyn Nets (BKN) - Scores: ['27', '19', '44', '19']
# -------------------------------------------
# Date: 2019-03-30T22:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['21', '27', '22', '26']
# Home Team: Brooklyn Nets (BKN) - Scores: ['17', '32', '33', '28']
# -------------------------------------------
# Date: 2019-11-29T17:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['24', '31', '26', '26']
# Home Team: Brooklyn Nets (BKN) - Scores: ['31', '27', '29', '25']
# -------------------------------------------
# Date: 2020-03-21
# Visitor Team: Boston Celtics (BOS) - Scores: ['0']
# Home Team: Brooklyn Nets (BKN) - Scores: ['0']
# -------------------------------------------
# Date: 2021-04-23T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['25', '26', '22', '31']
# Home Team: Brooklyn Nets (BKN) - Scores: ['21', '39', '28', '21']
# -------------------------------------------
# Date: 2021-06-05
# Visitor Team: Boston Celtics (BOS) - Scores: ['0']
# Home Team: Brooklyn Nets (BKN) - Scores: ['0']
# -------------------------------------------
# Date: 2021-03-12T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['29', '26', '31', '23']
# Home Team: Brooklyn Nets (BKN) - Scores: ['23', '35', '30', '33']
# -------------------------------------------
# Date: 2021-05-23T00:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['21', '32', '20', '20']
# Home Team: Brooklyn Nets (BKN) - Scores: ['16', '31', '31', '26']
# -------------------------------------------
# Date: 2021-05-25T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['26', '21', '35', '26']
# Home Team: Brooklyn Nets (BKN) - Scores: ['40', '31', '38', '21']
# -------------------------------------------
# Date: 2021-06-01T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['24', '27', '28', '30']
# Home Team: Brooklyn Nets (BKN) - Scores: ['31', '28', '27', '37']
# -------------------------------------------
# Date: 2022-02-09T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '34', '28', '29']
# Home Team: Brooklyn Nets (BKN) - Scores: ['16', '27', '28', '20']
# -------------------------------------------
# Date: 2022-02-25T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '32', '30', '32']
# Home Team: Brooklyn Nets (BKN) - Scores: ['22', '30', '22', '32']
# -------------------------------------------
# Date: 2022-04-23T23:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['30', '23', '28', '28']
# Home Team: Brooklyn Nets (BKN) - Scores: ['25', '25', '22', '31']
# -------------------------------------------
# Date: 2022-04-25T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['30', '28', '32', '26']
# Home Team: Brooklyn Nets (BKN) - Scores: ['26', '24', '28', '34']
# -------------------------------------------
# Date: 2022-04-29
# Visitor Team: Boston Celtics (BOS) - Scores: ['0']
# Home Team: Brooklyn Nets (BKN) - Scores: ['0']
# -------------------------------------------
# Date: 2022-12-04T23:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['35', '27', '13', '28']
# Home Team: Brooklyn Nets (BKN) - Scores: ['27', '23', '19', '23']
# -------------------------------------------
# Date: 2023-01-13T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['29', '31', '24', '25']
# Home Team: Brooklyn Nets (BKN) - Scores: ['31', '26', '25', '16']
# -------------------------------------------
# Date: 2023-11-05T00:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['34', '36', '21', '33']
# Home Team: Brooklyn Nets (BKN) - Scores: ['34', '24', '30', '26']
# -------------------------------------------
# Date: 2024-02-14T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: ['36', '36', '26', '20']
# Home Team: Brooklyn Nets (BKN) - Scores: ['30', '27', '25', '28']
# -------------------------------------------
# Date: 2024-11-14T00:30:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: []
# Home Team: Brooklyn Nets (BKN) - Scores: []
# -------------------------------------------
# Date: 2025-03-15T22:00:00.000Z
# Visitor Team: Boston Celtics (BOS) - Scores: []
# Home Team: Brooklyn Nets (BKN) - Scores: []
# -------------------------------------------
# Date: 2015-10-19T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '32', '22', '25']
# Home Team: Boston Celtics (BOS) - Scores: ['31', '28', '28', '24']
# -------------------------------------------
# Date: 2015-11-21T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['19', '23', '25', '28']
# Home Team: Boston Celtics (BOS) - Scores: ['23', '43', '25', '29']
# -------------------------------------------
# Date: 2016-01-02T20:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['31', '25', '25', '19']
# Home Team: Boston Celtics (BOS) - Scores: ['29', '26', '16', '26']
# -------------------------------------------
# Date: 2016-10-17T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['16', '34', '26', '23']
# Home Team: Boston Celtics (BOS) - Scores: ['29', '33', '32', '26']
# -------------------------------------------
# Date: 2016-10-26T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['31', '27', '23', '36']
# Home Team: Boston Celtics (BOS) - Scores: ['33', '31', '33', '25']
# -------------------------------------------
# Date: 2017-04-10T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['13', '27', '37', '28']
# Home Team: Boston Celtics (BOS) - Scores: ['28', '30', '32', '24']
# -------------------------------------------
# Date: 2017-12-31T22:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['28', '31', '17', '29']
# Home Team: Boston Celtics (BOS) - Scores: ['38', '23', '21', '26']
# -------------------------------------------
# Date: 2018-04-12T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['22', '21', '27', '27']
# Home Team: Boston Celtics (BOS) - Scores: ['27', '26', '30', '27']
# -------------------------------------------
# Date: 2019-01-08T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['22', '23', '29', '21']
# Home Team: Boston Celtics (BOS) - Scores: ['34', '22', '30', '30']
# -------------------------------------------
# Date: 2019-01-29T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '24', '38', '16']
# Home Team: Boston Celtics (BOS) - Scores: ['32', '28', '29', '23']
# -------------------------------------------
# Date: 2019-11-28T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['23', '40', '23', '24']
# Home Team: Boston Celtics (BOS) - Scores: ['30', '27', '34', '30']
# -------------------------------------------
# Date: 2020-03-04T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['28', '15', '24', '51', '11']
# Home Team: Boston Celtics (BOS) - Scores: ['33', '23', '28', '34', '2']
# -------------------------------------------
# Date: 2020-12-19T01:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['35', '27', '30', '21']
# Home Team: Boston Celtics (BOS) - Scores: ['23', '21', '16', '29']
# -------------------------------------------
# Date: 2020-12-25T22:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['26', '25', '35', '37']
# Home Team: Boston Celtics (BOS) - Scores: ['22', '32', '23', '18']
# -------------------------------------------
# Date: 2020-08-06T01:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['25', '27', '25', '38']
# Home Team: Boston Celtics (BOS) - Scores: ['34', '37', '35', '43']
# -------------------------------------------
# Date: 2021-05-29T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['32', '25', '27', '35']
# Home Team: Boston Celtics (BOS) - Scores: ['33', '28', '35', '29']
# -------------------------------------------
# Date: 2021-05-30T23:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '40', '39', '29']
# Home Team: Boston Celtics (BOS) - Scores: ['34', '26', '31', '35']
# -------------------------------------------
# Date: 2021-06-03
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['0']
# Home Team: Boston Celtics (BOS) - Scores: ['0']
# -------------------------------------------
# Date: 2021-11-25T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['29', '33', '35', '26']
# Home Team: Boston Celtics (BOS) - Scores: ['22', '27', '27', '28']
# -------------------------------------------
# Date: 2022-03-06T18:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['34', '26', '30', '30']
# Home Team: Boston Celtics (BOS) - Scores: ['29', '29', '31', '37']
# -------------------------------------------
# Date: 2022-04-17T19:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['28', '33', '24', '29']
# Home Team: Boston Celtics (BOS) - Scores: ['29', '32', '35', '19']
# -------------------------------------------
# Date: 2022-04-20T23:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '32', '25', '17']
# Home Team: Boston Celtics (BOS) - Scores: ['24', '31', '30', '29']
# -------------------------------------------
# Date: 2022-04-27T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['0']
# Home Team: Boston Celtics (BOS) - Scores: ['0']
# -------------------------------------------
# Date: 2022-05-01
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['0']
# Home Team: Boston Celtics (BOS) - Scores: ['0']
# -------------------------------------------
# Date: 2023-02-02T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['16', '29', '27', '24']
# Home Team: Boston Celtics (BOS) - Scores: ['46', '33', '31', '29']
# -------------------------------------------
# Date: 2023-03-04T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['15', '40', '34', '26']
# Home Team: Boston Celtics (BOS) - Scores: ['37', '27', '20', '21']
# -------------------------------------------
# Date: 2022-07-17T00:00:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: []
# Home Team: Boston Celtics (BOS) - Scores: []
# -------------------------------------------
# Date: 2023-11-11T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['33', '21', '30', '23']
# Home Team: Boston Celtics (BOS) - Scores: ['38', '28', '27', '28']
# -------------------------------------------
# Date: 2024-02-15T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: ['15', '17', '23', '31']
# Home Team: Boston Celtics (BOS) - Scores: ['30', '38', '33', '35']
# -------------------------------------------
# Date: 2024-11-09T00:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: []
# Home Team: Boston Celtics (BOS) - Scores: []
# -------------------------------------------
# Date: 2025-03-18T23:30:00.000Z
# Visitor Team: Brooklyn Nets (BKN) - Scores: []
# Home Team: Boston Celtics (BOS) - Scores: []
# -------------------------------------------
