# %%
import pandas as pd
import datetime as dt

# %%
# Read in CSV files
api_df = pd.read_csv('./data/2015-2024_apiGameScores.csv')
excel_df = pd.read_csv('./data/2022-2023_csvGameScores.csv')

print('API file')
print(api_df.head())
print('\n')

print('Excel file')
print(excel_df.head())
# Out:
# API file
#          date         visitor           home  visitor_points  home_points
# 0  2015-11-24  Boston Celtics  Atlanta Hawks            97.0        121.0
# 1  2016-04-09  Boston Celtics  Atlanta Hawks           107.0        118.0
# 2  2016-04-16  Boston Celtics  Atlanta Hawks           101.0        102.0
# 3  2016-04-19  Boston Celtics  Atlanta Hawks            72.0         89.0
# 4  2016-04-26  Boston Celtics  Atlanta Hawks            83.0        110.0
#
#
# Excel file
#          date             visitor                   home  visitor_points  \
# 0  2023-10-24  Los Angeles Lakers         Denver Nuggets             107
# 1  2023-10-24        Phoenix Suns  Golden State Warriors             108
# 2  2023-10-25       Atlanta Hawks      Charlotte Hornets             110
# 3  2023-10-25  Washington Wizards         Indiana Pacers             120
# 4  2023-10-25      Boston Celtics        New York Knicks             108
#
#    home_points
# 0          119
# 1          104
# 2          116
# 3          143
# 4          104

# %% [markdown]
# # Union

# %%
print(f"Api Data Frame has {len(api_df)} rows of data.")
print(f"Excel Date Frame has {len(excel_df)} rows of data.")
# Out:
# Api Data Frame has 12796 rows of data.
# Excel Date Frame has 1231 rows of data.

# %%
# Merge both data frames
merged_df = pd.concat([api_df, excel_df], keys='date', ignore_index=True)

# Order by 'date' column
merged_df = merged_df.sort_values(by='date').reset_index(drop=True)

# Display
merged_df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21140\1401214015.py:2: FutureWarning: The behavior of pd.concat with len(keys) != len(objs) is deprecated. In a future version this will raise instead of truncating to the smaller of the two sequences
#   merged_df = pd.concat([api_df, excel_df], keys='date', ignore_index=True)
#              date               visitor                   home  \
# 0      2015-10-02        Denver Nuggets            LA Clippers
# 1      2015-10-03  New Orleans Pelicans         Indiana Pacers
# 2      2015-10-03     Charlotte Hornets          Orlando Magic
# 3      2015-10-04             Utah Jazz     Los Angeles Lakers
# 4      2015-10-04     Charlotte Hornets             Miami Heat
# ...           ...                   ...                    ...
# 14022  2024-11-04        Boston Celtics          Atlanta Hawks
# 14023  2024-11-04        Indiana Pacers       Dallas Mavericks
# 14024  2024-11-04         Orlando Magic  Oklahoma City Thunder
# 14025  2024-11-04     San Antonio Spurs            LA Clippers
# 14026  2024-11-04    Los Angeles Lakers        Detroit Pistons
#
#        visitor_points  home_points
# 0                96.0        103.0
# 1               110.0        105.0
# 2               106.0        100.0
# 3                90.0         71.0
# 4                90.0         77.0
# ...               ...          ...
# 14022           123.0         93.0
# 14023           134.0        127.0
# 14024            86.0        102.0
# 14025           104.0        113.0
# 14026           103.0        115.0
#
# [14027 rows x 5 columns]

# %%
# Find total count of null values within each column
merged_df.isnull().sum()
# Out:
# date              0
# visitor           0
# home              0
# visitor_points    0
# home_points       0
# dtype: int64

# %%
# Find total count of duplicates
duplicate_count = len(merged_df[merged_df.duplicated()])
print(f"Total duplicates in merged data frame: {duplicate_count}")

# Display
merged_df[merged_df.duplicated()]
# Out:
# Total duplicates in merged data frame: 1227
#              date                 visitor                   home  \
# 11301  2023-10-24      Los Angeles Lakers         Denver Nuggets
# 11302  2023-10-24            Phoenix Suns  Golden State Warriors
# 11310  2023-10-25         Detroit Pistons             Miami Heat
# 11313  2023-10-25  Minnesota Timberwolves        Toronto Raptors
# 11316  2023-10-25   Oklahoma City Thunder          Chicago Bulls
# ...           ...                     ...                    ...
# 13756  2024-04-14           Atlanta Hawks         Indiana Pacers
# 13757  2024-04-14      Washington Wizards         Boston Celtics
# 13758  2024-04-14         Toronto Raptors             Miami Heat
# 13759  2024-04-14         Houston Rockets            LA Clippers
# 13760  2024-04-14         Detroit Pistons      San Antonio Spurs
#
#        visitor_points  home_points
# 11301           107.0        119.0
# 11302           108.0        104.0
# 11310           102.0        103.0
# 11313            94.0         97.0
# 11316           124.0        104.0
# ...               ...          ...
# 13756           115.0        157.0
# 13757           122.0        132.0
# 13758           103.0        118.0
# 13759           116.0        105.0
# 13760            95.0        123.0
#
# [1227 rows x 5 columns]

# %%
# Show example
merged_df.loc[(merged_df['visitor'] == 'Detroit Pistons')  & (merged_df['home'] == 'San Antonio Spurs')]
# Out:
#              date          visitor               home  visitor_points  \
# 69     2015-10-18  Detroit Pistons  San Antonio Spurs            92.0
# 996    2016-03-02  Detroit Pistons  San Antonio Spurs            81.0
# 1633   2016-11-11  Detroit Pistons  San Antonio Spurs            86.0
# 3310   2017-12-04  Detroit Pistons  San Antonio Spurs            93.0
# 4393   2018-10-05  Detroit Pistons  San Antonio Spurs            93.0
# 5348   2019-02-27  Detroit Pistons  San Antonio Spurs            93.0
# 6372   2019-12-28  Detroit Pistons  San Antonio Spurs           109.0
# 8002   2021-04-22  Detroit Pistons  San Antonio Spurs            91.0
# 8927   2021-12-26  Detroit Pistons  San Antonio Spurs           109.0
# 10503  2023-01-06  Detroit Pistons  San Antonio Spurs           109.0
# 13732  2024-04-14  Detroit Pistons  San Antonio Spurs            95.0
# 13760  2024-04-14  Detroit Pistons  San Antonio Spurs            95.0
#
#        home_points
# 69            96.0
# 996           97.0
# 1633          96.0
# 3310          96.0
# 4393         117.0
# 5348         105.0
# 6372         136.0
# 8002         106.0
# 8927         144.0
# 10503        121.0
# 13732        123.0
# 13760        123.0

# %%
# Drop duplicates
final_df = merged_df.drop_duplicates()

print(f"Total number of rows in final dataset is : {len(final_df)}")
# Out:
# Total number of rows in final dataset is : 12800

# %%
# Export as CSV file
final_df.to_csv(f'./data/finalMergedSet.csv', index=False)
