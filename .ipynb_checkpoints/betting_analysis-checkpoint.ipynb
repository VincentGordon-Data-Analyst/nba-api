# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import statistics

# %%
df = pd.read_csv(f'./data/finalMergedSet.csv')
df
# Out:
#              date                 visitor                  home  \
# 0      2015-10-02          Denver Nuggets           LA Clippers
# 1      2015-10-03    New Orleans Pelicans        Indiana Pacers
# 2      2015-10-03       Charlotte Hornets         Orlando Magic
# 3      2015-10-04       Charlotte Hornets            Miami Heat
# 4      2015-10-04             LA Clippers       Toronto Raptors
# ...           ...                     ...                   ...
# 12792  2024-11-04      Philadelphia 76ers          Phoenix Suns
# 12793  2024-11-04          Indiana Pacers      Dallas Mavericks
# 12794  2024-11-04        Sacramento Kings            Miami Heat
# 12795  2024-11-04      Los Angeles Lakers       Detroit Pistons
# 12796  2024-11-04  Portland Trail Blazers  New Orleans Pelicans
#
#        visitor_points  home_points
# 0                96.0        103.0
# 1               110.0        105.0
# 2               106.0        100.0
# 3                90.0         77.0
# 4                73.0         93.0
# ...               ...          ...
# 12792           116.0        118.0
# 12793           134.0        127.0
# 12794           111.0        110.0
# 12795           103.0        115.0
# 12796           118.0        100.0
#
# [12797 rows x 5 columns]

# %%
# Take games between chosen years
start_year = 2019
current_year = dt.datetime.now().year

# Convert to datetime data type
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filtered the dataframe for games between start year and current year
filtered_df = df[(df['date'].dt.year >= start_year) & (df['date'].dt.year <= current_year)]

# Reset data frame
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#            date                 visitor                  home  visitor_points  \
# 0    2019-01-01  Portland Trail Blazers      Sacramento Kings           113.0
# 1    2019-01-01      Philadelphia 76ers           LA Clippers           119.0
# 2    2019-01-01               Utah Jazz       Toronto Raptors           116.0
# 3    2019-01-01         New York Knicks        Denver Nuggets           108.0
# 4    2019-01-01         Detroit Pistons       Milwaukee Bucks            98.0
# ...         ...                     ...                   ...             ...
# 7807 2024-11-04      Philadelphia 76ers          Phoenix Suns           116.0
# 7808 2024-11-04          Indiana Pacers      Dallas Mavericks           134.0
# 7809 2024-11-04        Sacramento Kings            Miami Heat           111.0
# 7810 2024-11-04      Los Angeles Lakers       Detroit Pistons           103.0
# 7811 2024-11-04  Portland Trail Blazers  New Orleans Pelicans           118.0
#
#       home_points
# 0           108.0
# 1           113.0
# 2           122.0
# 3           115.0
# 4           121.0
# ...           ...
# 7807        118.0
# 7808        127.0
# 7809        110.0
# 7810        115.0
# 7811        100.0
#
# [7812 rows x 5 columns]

# %%
def possible_outcome(dataframe, away_team, home_team, first_line): 
    # Filter the dataframe for the specific matchup
    matchup_game = dataframe.loc[
        ((dataframe['visitor'] == away_team) & (dataframe['home'] == home_team)) | 
        ((dataframe['visitor'] == home_team) & (dataframe['home'] == away_team))
        ].copy()
    
    # Add a 'total_points' column 
    matchup_game['total_points'] = matchup_game['visitor_points'] + matchup_game['home_points']
    
    # Sort by date
    matchup_game = matchup_game.sort_values(by='date').reset_index(drop=True)
    
    # Determine the winner
    matchup_game['winner'] = matchup_game.apply(lambda row: home_team if row['home_points'] > row['visitor_points']  else away_team, axis=1)
    
    # Games with zero points are considered to be postponed
    # Keep rows where total_points is not zero
    matchup_game = matchup_game.loc[matchup_game['total_points'] != 0]
        
    # Create side-by-side plots
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
      
    # Plot total points distribution with a KDE
    sns.histplot(data=matchup_game, x='total_points', kde=True, ax=axes[0], color="skyblue")
    axes[0].set_title(f'Total Points Distribution for {away_team} vs {home_team}')
    
    # Plot the winner count    
    sns.countplot(data=matchup_game, x='winner', ax=axes[1], hue='winner')
    axes[1].set_title(f'Winner Counts: {away_team} vs {home_team}')
        
    # Display the plots
    plt.show()
    
     # Calculate a z-score from a provided mean and standard deviation
    mean = matchup_game['total_points'].mean()
    standard_deviation = matchup_game['total_points'].std()
   
    # Create array of UNDER/OVER values starting with given first line
    under_over_lines = [first_line + i for i in range(-7, 8)]
    
    # Display basic statics of team matchup
    print(f'Statistics of {away_team} vs {home_team}')
    print('\n')
    print(f'Mean: {mean}')
    print(f'Standard Deviation: {standard_deviation}')

    print('------------------------------------')
    # Display the z-scores for each line score
    for line in under_over_lines:
        zscore = statistics.NormalDist(mean, standard_deviation).zscore(line)
        print(f'z-score for {line}: {zscore:.2f}')

    # print('------------------------------------')

    # Find percentage of games between specified range
    # total_games = len(matchup_game)
    # games_in_range = matchup_game[(matchup_game['total_points'] >= lower_bound) & (matchup_game['total_points'] <= upper_bound)]
    # percentage = (len(games_in_range) / total_games) * 100
    # print(f"Percentage of games with total scores between {lower_bound} and {upper_bound}: {percentage:.2f}%")
    # print('------------------------------------')
    
    return matchup_game

away_team = input("Enter the away team: ")
home_team = input("Enter the home team: ")
first_line = float(input("Enter the first line for the over/under bet: "))


possible_outcome(filtered_df, away_team, home_team, first_line)
# Out:
# Statistics of Toronto Raptors vs Los Angeles Lakers
#
#
# Mean: 230.83333333333334
# Standard Deviation: 20.229741081942304
# ------------------------------------
# z-score for 229.5: -0.07
# z-score for 230.5: -0.02
# z-score for 231.5: 0.03
# z-score for 232.5: 0.08
# z-score for 233.5: 0.13
# z-score for 234.5: 0.18
# z-score for 235.5: 0.23
# z-score for 236.5: 0.28
# z-score for 237.5: 0.33
# z-score for 238.5: 0.38
# z-score for 239.5: 0.43
# z-score for 240.5: 0.48
# z-score for 241.5: 0.53
# z-score for 242.5: 0.58
# z-score for 243.5: 0.63
#          date             visitor                home  visitor_points  \
# 0  2019-03-14  Los Angeles Lakers     Toronto Raptors            98.0
# 1  2019-11-10     Toronto Raptors  Los Angeles Lakers           113.0
# 2  2020-08-01  Los Angeles Lakers     Toronto Raptors            92.0
# 3  2021-04-06  Los Angeles Lakers     Toronto Raptors           110.0
# 4  2021-05-02     Toronto Raptors  Los Angeles Lakers           121.0
# 5  2022-03-14     Toronto Raptors  Los Angeles Lakers           114.0
# 6  2022-03-18  Los Angeles Lakers     Toronto Raptors           128.0
# 7  2022-12-07  Los Angeles Lakers     Toronto Raptors           113.0
# 8  2023-03-10     Toronto Raptors  Los Angeles Lakers           112.0
# 9  2024-01-09     Toronto Raptors  Los Angeles Lakers           131.0
# 10 2024-04-02  Los Angeles Lakers     Toronto Raptors           128.0
# 11 2024-11-01  Los Angeles Lakers     Toronto Raptors           131.0
#
#     home_points  total_points              winner
# 0         111.0         209.0  Los Angeles Lakers
# 1         104.0         217.0     Toronto Raptors
# 2         107.0         199.0  Los Angeles Lakers
# 3         101.0         211.0     Toronto Raptors
# 4         114.0         235.0     Toronto Raptors
# 5         103.0         217.0     Toronto Raptors
# 6         123.0         251.0     Toronto Raptors
# 7         126.0         239.0  Los Angeles Lakers
# 8         122.0         234.0  Los Angeles Lakers
# 9         132.0         263.0  Los Angeles Lakers
# 10        111.0         239.0     Toronto Raptors
# 11        125.0         256.0     Toronto Raptors

# %%
teams = df['visitor'].unique()
teams.sort()
teams
# Out:
# array(['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets',
#        'Charlotte Hornets', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons',
#        'Golden State Warriors', 'Houston Rockets', 'Indiana Pacers',
#        'LA Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies',
#        'Miami Heat', 'Milwaukee Bucks', 'Minnesota Timberwolves',
#        'New Orleans Pelicans', 'New York Knicks', 'Oklahoma City Thunder',
#        'Orlando Magic', 'Philadelphia 76ers', 'Phoenix Suns',
#        'Portland Trail Blazers', 'Sacramento Kings', 'San Antonio Spurs',
#        'Toronto Raptors', 'Utah Jazz', 'Washington Wizards'], dtype=object)
