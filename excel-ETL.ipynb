# %%
import pandas as pd
import datetime as dt

games_df = pd.read_csv('./data/nba-2022-EasternStandardTime.csv')
games_df
# Out:
#       Match Number  Round Number              Date               Location  \
# 0                1             1  18/10/2022 19:30              TD Garden
# 1                2             1  18/10/2022 22:00           Chase Center
# 2                3             1  19/10/2022 19:00   Little Caesars Arena
# 3                4             1  19/10/2022 19:00  Gainbridge Fieldhouse
# 4                5             1  19/10/2022 19:30       State Farm Arena
# ...            ...           ...               ...                    ...
# 1225          1226            24  09/04/2023 15:30          Paycom Center
# 1226          1227            24  09/04/2023 15:30             Ball Arena
# 1227          1228            24  09/04/2023 15:30       Crypto.com Arena
# 1228          1229            24  09/04/2023 15:30       Footprint Center
# 1229          1230            24  09/04/2023 15:30            Moda Center
#
#                    Home Team              Away Team     Result
# 0             Boston Celtics     Philadelphia 76ers  126 - 117
# 1      Golden State Warriors     Los Angeles Lakers  123 - 109
# 2            Detroit Pistons          Orlando Magic  113 - 109
# 3             Indiana Pacers     Washington Wizards  107 - 114
# 4              Atlanta Hawks        Houston Rockets  117 - 107
# ...                      ...                    ...        ...
# 1225   Oklahoma City Thunder      Memphis Grizzlies  115 - 100
# 1226          Denver Nuggets       Sacramento Kings   109 - 95
# 1227      Los Angeles Lakers              Utah Jazz  128 - 117
# 1228            Phoenix Suns            LA Clippers  114 - 119
# 1229  Portland Trail Blazers  Golden State Warriors  101 - 157
#
# [1230 rows x 7 columns]

# %% [markdown]
# # Game Information

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Match Number  1230 non-null   int64
#  1   Round Number  1230 non-null   int64
#  2   Date          1230 non-null   object
#  3   Location      1230 non-null   object
#  4   Home Team     1230 non-null   object
#  5   Away Team     1230 non-null   object
#  6   Result        1230 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 67.4+ KB

# %%
# Find total number of null values from each column
games_df.isnull().sum()
# Out:
# Match Number    0
# Round Number    0
# Date            0
# Location        0
# Home Team       0
# Away Team       0
# Result          0
# dtype: int64

# %%
# Select specific columns
games_df = games_df[['Date', 'Home Team', 'Away Team', 'Result']]

# Display first five rows
games_df
# Out:
#                   Date               Home Team              Away Team  \
# 0     18/10/2022 19:30          Boston Celtics     Philadelphia 76ers
# 1     18/10/2022 22:00   Golden State Warriors     Los Angeles Lakers
# 2     19/10/2022 19:00         Detroit Pistons          Orlando Magic
# 3     19/10/2022 19:00          Indiana Pacers     Washington Wizards
# 4     19/10/2022 19:30           Atlanta Hawks        Houston Rockets
# ...                ...                     ...                    ...
# 1225  09/04/2023 15:30   Oklahoma City Thunder      Memphis Grizzlies
# 1226  09/04/2023 15:30          Denver Nuggets       Sacramento Kings
# 1227  09/04/2023 15:30      Los Angeles Lakers              Utah Jazz
# 1228  09/04/2023 15:30            Phoenix Suns            LA Clippers
# 1229  09/04/2023 15:30  Portland Trail Blazers  Golden State Warriors
#
#          Result
# 0     126 - 117
# 1     123 - 109
# 2     113 - 109
# 3     107 - 114
# 4     117 - 107
# ...         ...
# 1225  115 - 100
# 1226   109 - 95
# 1227  128 - 117
# 1228  114 - 119
# 1229  101 - 157
#
# [1230 rows x 4 columns]

# %%
# Split 'Result' column
games_df[['Home Points', 'Away Points']] = games_df['Result'].str.split('-', expand=True)

# Drop 'Result' column
games_df = games_df.drop(columns=['Result'])

games_df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3420\2201120922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_df[['Home Points', 'Away Points']] = games_df['Result'].str.split('-', expand=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_3420\2201120922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_df[['Home Points', 'Away Points']] = games_df['Result'].str.split('-', expand=True)
#                Date              Home Team           Away Team Home Points  \
# 0  18/10/2022 19:30         Boston Celtics  Philadelphia 76ers        126
# 1  18/10/2022 22:00  Golden State Warriors  Los Angeles Lakers        123
# 2  19/10/2022 19:00        Detroit Pistons       Orlando Magic        113
# 3  19/10/2022 19:00         Indiana Pacers  Washington Wizards        107
# 4  19/10/2022 19:30          Atlanta Hawks     Houston Rockets        117
#
#   Away Points
# 0         117
# 1         109
# 2         109
# 3         114
# 4         107

# %%
# Rename columns
games_df = games_df.rename(columns={
    'Date': 'date',
    'Home Team': 'home',
    'Away Team': 'visitor',
    'Home Points': 'home_points',
    'Away Points': 'visitor_points'
})

# Rearrange columns
games_df = games_df[['date', 'visitor', 'home', 'visitor_points', 'home_points']]

# Display first five rows
games_df.head()
# Out:
#                date             visitor                   home visitor_points  \
# 0  18/10/2022 19:30  Philadelphia 76ers         Boston Celtics            117
# 1  18/10/2022 22:00  Los Angeles Lakers  Golden State Warriors            109
# 2  19/10/2022 19:00       Orlando Magic        Detroit Pistons            109
# 3  19/10/2022 19:00  Washington Wizards         Indiana Pacers            114
# 4  19/10/2022 19:30     Houston Rockets          Atlanta Hawks            107
#
#   home_points
# 0        126
# 1        123
# 2        113
# 3        107
# 4        117

# %%
# Convert to datetime column
games_df['date'] = pd.to_datetime(games_df['date'], errors='coerce')

# Change the format of the date columns
games_df['date'] = games_df['date'].dt.strftime('%Y-%m-%d')

# Display
games_df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3420\1220396035.py:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   games_df['date'] = pd.to_datetime(games_df['date'], errors='coerce')
#          date             visitor                   home visitor_points  \
# 0  2022-10-18  Philadelphia 76ers         Boston Celtics            117
# 1  2022-10-18  Los Angeles Lakers  Golden State Warriors            109
# 2  2022-10-19       Orlando Magic        Detroit Pistons            109
# 3  2022-10-19  Washington Wizards         Indiana Pacers            114
# 4  2022-10-19     Houston Rockets          Atlanta Hawks            107
#
#   home_points
# 0        126
# 1        123
# 2        113
# 3        107
# 4        117

# %%
# Export to excel file
games_df.to_csv('./data/2022-2023_csvGameScores.csv', index=False)
